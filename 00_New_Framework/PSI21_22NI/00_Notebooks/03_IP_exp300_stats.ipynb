# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - exp 1XX acquisition 00

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI_updated_framework\03_ Stats\01_overlap_sep"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI_updated_framework\03_ Stats\01_transmission_1h"

# %% [markdown]
# ### Check folders to process

# %%
stack_dict = prep_stack_dict(src_dir)
for key in stack_dict.keys():
    print(key)
# Out:
# 006_temp_03_p20_ob
# f0
# f1
# f2

# %%
#proc_folder = ['005_temp_02_p20_prot']
#ref_folder = ['098_ref_bb']

# %% [markdown]
# ## Process the reference folder (if not done before)
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
#%store -r exp_param
ref_dir =  r"J:\700 Campaigns - internal\2021\PSI21_22NI_updated_framework\01_Transmission_results\exp300"
ref_dict = read_saved_dict (ref_dir, proc_folder = ['098_ref_bb'])
# Out:
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  3.71it/s]

# %% [markdown]
# ### Continue here if ref images are not done
# if the ref images were done (with the same processing intended) then continue to section 3

# %%
#ref_param = {}
#nca_ref = [388, 10, 59, 488]

#add_to_dict(ref_param, ['threshold', 'ws_filter_size'], [0, 3])

# %%
#ref_seq =  [stack_averaging,
#            ob_roi_mod_dict,
#            scrubbing_correction_dict,
#            ws_filter,
#            outlier_removal,
#            SBKG_correction_dict]

# %%
#proc_folder = ref_folder
#BB_mask = get_img(src_dir + '/bb_mask_ref.fits')
#add_to_dict(ref_param,['BB_mask'], [BB_mask])

#ref_dict = full_processing (src_dir, dst_dir, proc_folder = ref_folder, sequence = ref_seq, 
#                 proc_parameters = ref_param, img_name = 'intensity', save = True)

# %% [markdown]
# ## Gettinging an NCA

# %%
#test_folder01 = ['001_temp_00_m25_prot']

#img_dict01, _ = testing_mode_step (src_dir, proc_folder = test_folder01, keep_acq_numb = 1)

# %%
#img_batch01 = avg_frames_dict (img_dict01[test_folder01[0]], output_type = 'img')

# %%
# %load select_rois(img_batch01, list_rois = ['nca'])
nca = [96, 375, 327, 112]

# %%
#show_img(img_batch01[0], dr = [(nca, 'blue')], cmap='gray')

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}

add_to_dict(exp_param, ['threshold', 'use_ref', 'ref_dict', 'ws_filter_size'], [0, True, ref_dict, 3])

# %%
exp_seq =  [outlier_removal,
            #stack_averaging,
            ob_roi_mod_dict,
            ws_filter,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            intensity_correction_dict,
            referencing_dict]

# %% [markdown]
# ## Exp301 Processing

# %% [markdown]
# ### Processing all

# %%
proc_folder = ['f0']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:07<00:00,  3.55s/it]
# Experiment f0 in process...
# Processing Filetring : 100%|█████████████████████| 5/5 [02:11<00:00, 26.24s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [01:49<00:00, 10.90s/it]
# Processing ob mod correction: 100%|██████████████| 5/5 [00:00<00:00,  5.40it/s]
# Processing Filetring : 100%|█████████████████████| 5/5 [00:12<00:00,  2.41s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:24<00:00,  2.41s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:02<00:00,  4.89it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [04:25<00:00, 26.54s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  6.03it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:03<00:00,  3.27it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:35<00:00,  3.54s/it]
# Total time: 600s

# %%
proc_folder = ['f1']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:05<00:00,  2.83s/it]
# Experiment f1 in process...
# Processing Filetring : 100%|█████████████████████| 5/5 [00:01<00:00,  2.55it/s]
# Processing Filetring : 100%|███████████████████| 10/10 [01:54<00:00, 11.45s/it]
# Processing ob mod correction: 100%|██████████████| 5/5 [00:00<00:00,  5.26it/s]
# Processing Filetring : 100%|█████████████████████| 5/5 [00:11<00:00,  2.39s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:23<00:00,  2.37s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:01<00:00,  5.31it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [04:17<00:00, 25.70s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  5.95it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:02<00:00,  3.35it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:36<00:00,  3.65s/it]
# Total time: 472s

# %%
proc_folder = ['f2']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:06<00:00,  3.22s/it]
# Experiment f2 in process...
# Processing Filetring : 100%|█████████████████████| 5/5 [00:41<00:00,  8.30s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [01:37<00:00,  9.79s/it]
# Processing ob mod correction: 100%|██████████████| 5/5 [00:00<00:00,  5.43it/s]
# Processing Filetring : 100%|█████████████████████| 5/5 [00:11<00:00,  2.34s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:23<00:00,  2.34s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:01<00:00,  5.20it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [04:15<00:00, 25.59s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  6.12it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:03<00:00,  3.29it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:35<00:00,  3.60s/it]
# Total time: 488s

# %%
proc_folder = ['f3']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:05<00:00,  2.56s/it]
# Experiment f3 in process...
# Processing Filetring : 100%|█████████████████████| 3/3 [00:28<00:00,  9.65s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [01:49<00:00, 10.91s/it]
# Processing ob mod correction: 100%|██████████████| 3/3 [00:00<00:00,  5.63it/s]
# Processing Filetring : 100%|█████████████████████| 3/3 [00:07<00:00,  2.36s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:23<00:00,  2.33s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:01<00:00,  5.20it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [08:33<00:00, 51.40s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  6.07it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:07<00:00,  1.41it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:35<00:00,  3.51s/it]
# Total time: 745s

# %%
proc_folder = ['f4']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:04<00:00,  2.33s/it]
# Experiment f4 in process...
# Processing Filetring : 100%|█████████████████████| 3/3 [00:30<00:00, 10.04s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [01:48<00:00, 10.82s/it]
# Processing ob mod correction: 100%|██████████████| 3/3 [00:00<00:00,  5.81it/s]
# Processing Filetring : 100%|█████████████████████| 3/3 [00:07<00:00,  2.36s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:23<00:00,  2.34s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:01<00:00,  5.28it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [04:49<00:00, 28.99s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  5.79it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:11<00:00,  1.13s/it]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:35<00:00,  3.52s/it]
# Total time: 529s

# %%
proc_folder = ['f5']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:04<00:00,  2.50s/it]
# Experiment f5 in process...
# Processing Filetring : 100%|█████████████████████| 3/3 [00:28<00:00,  9.60s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [01:50<00:00, 11.03s/it]
# Processing ob mod correction: 100%|██████████████| 3/3 [00:00<00:00,  5.68it/s]
# Processing Filetring : 100%|█████████████████████| 3/3 [00:07<00:00,  2.35s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:23<00:00,  2.33s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:01<00:00,  5.19it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [04:30<00:00, 27.08s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  5.91it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:11<00:00,  1.12s/it]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:35<00:00,  3.53s/it]
# Total time: 515s

# %%
proc_folder = ['f6']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:04<00:00,  2.39s/it]
# Experiment f6 in process...
# Processing Filetring : 100%|█████████████████████| 3/3 [00:29<00:00,  9.96s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [01:50<00:00, 11.05s/it]
# Processing ob mod correction: 100%|██████████████| 3/3 [00:00<00:00,  5.69it/s]
# Processing Filetring : 100%|█████████████████████| 3/3 [00:07<00:00,  2.36s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:23<00:00,  2.34s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:01<00:00,  5.28it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [04:15<00:00, 25.59s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  5.67it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:25<00:00,  2.59s/it]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:35<00:00,  3.56s/it]
# Total time: 507s

# %%
proc_folder = ['f7']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:07<00:00,  3.92s/it]
# Experiment f7 in process...
# Processing Filetring : 100%|█████████████████████| 3/3 [01:01<00:00, 20.39s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [02:54<00:00, 17.42s/it]
# Processing ob mod correction: 100%|██████████████| 3/3 [00:00<00:00,  5.48it/s]
# Processing Filetring : 100%|█████████████████████| 3/3 [00:07<00:00,  2.35s/it]
# Processing Filetring : 100%|███████████████████| 10/10 [00:23<00:00,  2.33s/it]
# Processing Scrubbing Correction: 100%|█████████| 10/10 [00:01<00:00,  5.25it/s]
# Processing SBKG Correction: 100%|██████████████| 10/10 [04:17<00:00, 25.70s/it]
# Processing intensity Correction: 100%|█████████| 10/10 [00:01<00:00,  5.63it/s]
# Processing Referencing Correction: 100%|███████| 10/10 [00:11<00:00,  1.11s/it]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 10/10 [00:35<00:00,  3.53s/it]
# Total time: 600s

# %%
proc_folder = ['f8']
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission_stats', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 2/2 [00:05<00:00,  2.53s/it]
# Experiment f8 in process...
# Processing Filetring : 100%|█████████████████████| 3/3 [00:29<00:00,  9.89s/it]
# Processing Filetring : 100%|█████████████████████| 9/9 [01:38<00:00, 10.92s/it]
# Processing ob mod correction: 100%|██████████████| 3/3 [00:00<00:00,  5.58it/s]
# Processing Filetring : 100%|█████████████████████| 3/3 [00:07<00:00,  2.35s/it]
# Processing Filetring : 100%|█████████████████████| 9/9 [00:21<00:00,  2.34s/it]
# Processing Scrubbing Correction: 100%|███████████| 9/9 [00:01<00:00,  5.29it/s]
# Processing SBKG Correction: 100%|████████████████| 9/9 [03:51<00:00, 25.68s/it]
# Processing intensity Correction: 100%|███████████| 9/9 [00:01<00:00,  6.32it/s]
# Processing Referencing Correction: 100%|█████████| 9/9 [00:02<00:00,  3.40it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 9/9 [00:31<00:00,  3.54s/it]
# Total time: 443s
