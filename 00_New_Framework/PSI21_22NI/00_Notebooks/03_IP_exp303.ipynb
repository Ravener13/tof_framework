# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - exp 1XX acquisition 00

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp303"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI_updated_framework\01_Transmission_results\exp303"

# %% [markdown]
# ### Check folders to process

# %%
stack_dict = prep_stack_dict(src_dir)
for key in stack_dict.keys():
    print(key)
# Out:
# 000_temp_00_m5_ob
# 001_temp_00_m5_prot
# 002_temp_01_p10_ob
# 003_temp_01_p10_prot
# 004_temp_02_p40_ob
# 005_temp_02_p40_prot
# 006_temp_00_p0_ob
# 097_ob
# 098_ref_bb
# 099_ob

# %%
proc_folder1 = ['001_temp_00_m5_prot']
proc_folder2 = ['003_temp_01_p10_prot']
proc_folder3 = ['005_temp_02_p40_prot']
ref_folder = ['098_ref_bb']

# %% [markdown]
# ## Process the reference folder (if not done before)
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
#%store -r exp_param
ref_dir =  r"J:\700 Campaigns - internal\2021\PSI21_22NI_updated_framework\01_Transmission_results\exp300"
ref_dict = read_saved_dict (ref_dir, proc_folder = ['098_ref_bb'])
# Out:
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  4.32it/s]

# %% [markdown]
# ### Continue here if ref images are not done
# if the ref images were done (with the same processing intended) then continue to section 3

# %%
#ref_param = {}
#nca_ref = [388, 10, 59, 488]

#add_to_dict(ref_param, ['threshold', 'ws_filter_size'], [0, 3])

# %%
#ref_seq =  [stack_averaging,
#            ob_roi_mod_dict,
#            scrubbing_correction_dict,
#            ws_filter,
#            outlier_removal,
#            SBKG_correction_dict]

# %%
#proc_folder = ref_folder
#BB_mask = get_img(src_dir + '/bb_mask_ref.fits')
#add_to_dict(ref_param,['BB_mask'], [BB_mask])

#ref_dict = full_processing (src_dir, dst_dir, proc_folder = ref_folder, sequence = ref_seq, 
#                 proc_parameters = ref_param, img_name = 'intensity', save = True)

# %% [markdown]
# ## Gettinging an NCA

# %%
test_folder01 = ['001_temp_00_m5_prot']

img_dict01, _ = testing_mode_step (src_dir, proc_folder = test_folder01, keep_acq_numb = 1)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.14s/it]

# %%
img_batch01 = avg_frames_dict (img_dict01[test_folder01[0]], output_type = 'img')

# %%
# %load select_rois(img_batch01, list_rois = ['nca'])
nca = [96, 375, 327, 112]

# %%
show_img(img_batch01[0], dr = [(nca, 'blue')], cmap='gray')

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}

add_to_dict(exp_param, ['threshold', 'use_ref', 'ref_dict', 'ws_filter_size'], [0, True, ref_dict, 3])

# %%
exp_seq =  [outlier_removal,
            stack_averaging,
            ob_roi_mod_dict,
            #ws_filter,
            scrubbing_correction_dict,
            #SBKG_correction_dict,
            intensity_correction_dict,
            referencing_dict]

# %% [markdown]
# ## Exp301 Processing

# %% [markdown]
# ### Processing all

# %%
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder1, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission', save = True)
# Out:
# Reading Images:  33%|█████████▎                  | 1/3 [00:02<00:05,  2.63s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [21], in <cell line: 4>()
#       1 BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
#       2 add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])
# ----> 4 exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder1, sequence = exp_seq,
#       5                  proc_parameters = exp_param, img_name = 'transmission', save = True)
#
# File ~\Documents\Python Scripts\tof_framework\00_New_Framework\PSI21_22NI\00_Notebooks\..\01_Functions\step_functions.py:186, in full_processing(src_dir, dst_dir, proc_folder, sequence, proc_parameters, img_name, save, testing, **kwargs)
#     183     proc_dict, weights_DataFrame = testing_mode_step (src_dir, proc_folder = proc_folder, **param_dict)
#     185 else:
# --> 186     proc_dict, weights_DataFrame = reading_step (src_dir, proc_folder = proc_folder, **param_dict)
#     188 param_dict.update(weights_DataFrame)
#     190 functions_dict = {'scrubbing_correction_dict' : scrubbing_correction_dict,
#     191                   'image_registration_dict': image_registration_dict,
#     192                   'SBKG_correction_dict': SBKG_correction_dict,
#    (...)
#     196                   'ob_roi_mod_dict' : ob_roi_mod_dict,
#     197                   }
#
# File ~\Documents\Python Scripts\tof_framework\00_New_Framework\PSI21_22NI\00_Notebooks\..\01_Functions\step_functions.py:37, in reading_step(src_dir, proc_folder, **kwargs)
#      34 keep_folder = proc_folder
#      35 keep_key_weights (stack_dict, weights_DataFrame, keep_folder)
# ---> 37 get_imgs_dict(stack_dict)
#      39 param_dict ['weights_DataFrame'] = weights_DataFrame
#      41 return stack_dict, param_dict
#
# File ~\Documents\Python Scripts\tof_framework\00_New_Framework\PSI21_22NI\00_Notebooks\..\01_Functions\dict_functions.py:90, in get_imgs_dict(stack_dict, **kwargs)
#      87 values = [item for item in stack_dict.values()]
#      88 for idx, key,value in zip (tqdm(range(len(stack_dict)), desc = 'Reading Images'),keys, values):
# ---> 90     val_imgs = [[get_img(item) for item in sub_val] for sub_val in value]
#      92     stack_dict [key] = val_imgs
#
# File ~\Documents\Python Scripts\tof_framework\00_New_Framework\PSI21_22NI\00_Notebooks\..\01_Functions\dict_functions.py:90, in <listcomp>(.0)
#      87 values = [item for item in stack_dict.values()]
#      88 for idx, key,value in zip (tqdm(range(len(stack_dict)), desc = 'Reading Images'),keys, values):
# ---> 90     val_imgs = [[get_img(item) for item in sub_val] for sub_val in value]
#      92     stack_dict [key] = val_imgs
#
# File ~\Documents\Python Scripts\tof_framework\00_New_Framework\PSI21_22NI\00_Notebooks\..\01_Functions\dict_functions.py:90, in <listcomp>(.0)
#      87 values = [item for item in stack_dict.values()]
#      88 for idx, key,value in zip (tqdm(range(len(stack_dict)), desc = 'Reading Images'),keys, values):
# ---> 90     val_imgs = [[get_img(item) for item in sub_val] for sub_val in value]
#      92     stack_dict [key] = val_imgs
#
# File ~\Documents\Python Scripts\tof_framework\00_New_Framework\PSI21_22NI\00_Notebooks\..\01_Functions\img_functions.py:51, in get_img(file_name, base_dir, squeeze)
#      48 warnings.simplefilter("ignore")
#      50     # open the file and get the image data
# ---> 51 with fits.open(os.path.join(base_dir, file_name)) as hdul:
#      52     timestamp = hdul[0].header
#      53     img = hdul[0].data
#
# File ~\AppData\Roaming\Python\Python39\site-packages\astropy\io\fits\hdu\hdulist.py:175, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     172 if not name:
#     173     raise ValueError(f'Empty filename: {name!r}')
# --> 175 return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     176                         lazy_load_hdus, ignore_missing_simple, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\astropy\io\fits\hdu\hdulist.py:410, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     398 @classmethod
#     399 def fromfile(cls, fileobj, mode=None, memmap=None,
#     400              save_backup=False, cache=True, lazy_load_hdus=True,
#     401              ignore_missing_simple=False, **kwargs):
#     402     """
#     403     Creates an `HDUList` instance from a file-like object.
#     404
#    (...)
#     407     documentation for details of the parameters accepted by this method).
#     408     """
# --> 410     return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     411                          save_backup=save_backup, cache=cache,
#     412                          ignore_missing_simple=ignore_missing_simple,
#     413                          lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\astropy\io\fits\hdu\hdulist.py:1060, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#    1057 if fileobj is not None:
#    1058     if not isinstance(fileobj, _File):
#    1059         # instantiate a FITS file object (ffo)
# -> 1060         fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1061     # The Astropy mode is determined by the _File initializer if the
#    1062     # supplied mode was None
#    1063     mode = fileobj.mode
#
# File ~\AppData\Roaming\Python\Python39\site-packages\astropy\io\fits\file.py:170, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache)
#     168     self._open_fileobj(fileobj, mode, overwrite)
#     169 elif isinstance(fileobj, (str, bytes)):
# --> 170     self._open_filename(fileobj, mode, overwrite)
#     171 else:
#     172     self._open_filelike(fileobj, mode, overwrite)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\astropy\io\fits\file.py:562, in _File._open_filename(self, filename, mode, overwrite)
#     559 ext = os.path.splitext(self.name)[1]
#     561 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 562     self._file = open(self.name, IO_FITS_MODES[mode])
#     563     self.close_on_error = True
#     565 # Make certain we're back at the beginning of the file
#     566 # BZ2File does not support seek when the file is open for writing, but
#     567 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# KeyboardInterrupt:

# %%
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder2, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:23<00:00,  7.84s/it]
# Experiment 003_temp_01_p10_prot in process...
# Processing Filetring : 100%|█████████████████████| 5/5 [00:43<00:00,  8.63s/it]
# Processing Filetring : 100%|███████████████████| 30/30 [04:31<00:00,  9.04s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [00:42<00:00,  8.51s/it]
# Processing ob mod correction: 100%|██████████████| 1/1 [00:00<00:00,  4.42it/s]
# Processing ob mod correction: 100%|██████████████| 1/1 [00:00<00:00,  5.17it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.40it/s]
# Processing intensity Correction: 100%|███████████| 1/1 [00:00<00:00,  5.45it/s]
# Processing Referencing Correction: 100%|█████████| 1/1 [00:00<00:00,  3.41it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:03<00:00,  3.50s/it]
# Total time: 406s

# %%
BB_mask = get_img(src_dir + '/bb_mask_prot.fits')
add_to_dict(exp_param,['BB_mask', 'nca'], [BB_mask, nca])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder3, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:16<00:00,  5.60s/it]
# Experiment 005_temp_02_p40_prot in process...
# Processing Filetring : 100%|█████████████████████| 5/5 [00:02<00:00,  2.40it/s]
# Processing Filetring : 100%|███████████████████| 26/26 [03:54<00:00,  9.03s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [00:45<00:00,  9.08s/it]
# Processing ob mod correction: 100%|██████████████| 1/1 [00:00<00:00,  4.72it/s]
# Processing ob mod correction: 100%|██████████████| 1/1 [00:00<00:00,  4.94it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.25it/s]
# Processing intensity Correction: 100%|███████████| 1/1 [00:00<00:00,  5.83it/s]
# Processing Referencing Correction: 100%|█████████| 1/1 [00:00<00:00,  3.42it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:03<00:00,  3.41s/it]
# Total time: 320s
