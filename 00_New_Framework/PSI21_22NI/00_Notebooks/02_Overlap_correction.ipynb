# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod_IMAT22 import *

# %% [markdown]
# ## Overlap Correction

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2021\PSI21_22NI\110_raw_sorted\exp210\02_temp_m23_full_prot"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp210"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 1, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = '')
# Out:
# Processing Overlap Correction: 100%|███████████| 18/18 [03:32<00:00, 11.83s/it]
# Processing Overlap Correction: 100%|███████████| 50/50 [10:04<00:00, 12.09s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2021\PSI21_22NI\110_raw_sorted\ref_bb"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp210"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 1, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = '')
# Out:
# Processing Overlap Correction: 100%|███████████| 14/14 [01:27<00:00,  6.22s/it]
# Processing Overlap Correction: 100%|█████████████| 8/8 [00:46<00:00,  5.83s/it]
# Processing Overlap Correction: 100%|█████████████| 7/7 [00:40<00:00,  5.76s/it]
# Experiments not processed due to low counts (counts threshold) are:  []
