# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod_IMAT22 import *

# %% [markdown]
# ## Overlap Correction HE

# %%
# %load select_directory('src')
src = r"H:\700 Campaigns - internal\780 2020\PSI20_01NI\temp\exps_HE"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2020\PSI20_01NI\00_Overlap_corrected\HE"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 5, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 6/6 [04:50<00:00, 48.44s/it]
# Processing Overlap Correction: 100%|███████████| 36/36 [29:30<00:00, 49.18s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [04:55<00:00, 49.17s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src_ref')
src_ref = r"H:\700 Campaigns - internal\780 2020\PSI20_01NI\temp\refs\99_ref"

# %%
# %load select_directory('dst_ref')
dst_ref = dst

# %%
mcpoc_correct_batch(src_ref, dst_ref, ref_sh_count = 'auto', exp_threshold= 100 , binning = 5, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 6/6 [08:54<00:00, 89.15s/it]
# Processing Overlap Correction: 100%|███████| 112/112 [2:47:01<00:00, 89.47s/it]
# Processing Overlap Correction: 100%|███████████| 10/10 [14:39<00:00, 87.97s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %% [markdown]
# ## Overlap Correction LE

# %%
# %load select_directory('src')
src = r"H:\700 Campaigns - internal\780 2020\PSI20_01NI\temp\exps_LE"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2020\PSI20_01NI\00_Overlap_corrected\LE"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 20, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 2/2 [01:36<00:00, 48.30s/it]
# Processing Overlap Correction: 100%|███████████| 10/10 [08:07<00:00, 48.75s/it]
# Processing Overlap Correction: 100%|█████████████| 2/2 [01:34<00:00, 47.39s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src_ref')
src_ref = r"H:\700 Campaigns - internal\780 2020\PSI20_01NI\temp\refs\99_ref_lw"

# %%
# %load select_directory('dst_ref')
dst_ref = dst

# %%
mcpoc_correct_batch(src_ref, dst_ref, ref_sh_count = 'auto', exp_threshold= 100 , binning = 20, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:31<00:00, 91.58s/it]
# Processing Overlap Correction: 100%|█████████████| 3/3 [04:38<00:00, 93.00s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:33<00:00, 93.20s/it]
# Experiments not processed due to low counts (counts threshold) are:  []
