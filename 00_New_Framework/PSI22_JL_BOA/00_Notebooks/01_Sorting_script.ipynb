# %% [markdown]
# # Image processing notebook: Sorting script or MCP with metadata.txt
#
#
# it is better to do it exp by exp
#
# The dst folder will have two numbers as identifiers at the beginning, they are in order according to the processing

# %%
import sys
sys.path.append(r'..\01_Functions')
from extra_functions import *

# %% [markdown]
# ### Fisrt folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\exp204"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp204"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|███████████████████████████████| 9/9 [46:01<00:00, 306.82s/it]

# %% [markdown]
# ### Second folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\exp205"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp205"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|███████████████████████████████| 7/7 [54:41<00:00, 468.77s/it]

# %% [markdown]
# ### third folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\exp202"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp202"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|███████████████████████████████| 4/4 [28:26<00:00, 426.55s/it]

# %% [markdown]
# ### fourth folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\exp203"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp203"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|███████████████████████████████| 5/5 [30:09<00:00, 361.83s/it]
