# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod import *

# %% [markdown]
# ## Overlap Correction Exp204

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp204"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\01_Overlap_corrected\exp204"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# ...
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:50<00:00, 28.47s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %% [markdown]
# ## Overlap Correction Exp205

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp205"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\01_Overlap_corrected\exp205"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# ...
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:55<00:00, 29.25s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %% [markdown]
# ## Overlap Correction Exp202

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp202"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\01_Overlap_corrected\exp202"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# ...
# Processing Overlap Correction: 100%|███████████| 35/35 [16:43<00:00, 28.66s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %% [markdown]
# ## Overlap Correction Exp203

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\00_Sorted\exp203"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_JL_BOA\00_Processed\01_Overlap_corrected\exp203"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# ...
# Processing Overlap Correction: 100%|█████████████| 7/7 [03:22<00:00, 28.92s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []
