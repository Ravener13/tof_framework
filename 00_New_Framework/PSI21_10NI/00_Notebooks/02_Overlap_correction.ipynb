# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod import *

# %% [markdown]
# ## Overlap Correction Exp102

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\00_Raw_sorted\exp102"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\01_Overlap_corrected\exp102"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 9000, exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:53<00:00, 28.85s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:57<00:00, 29.61s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:54<00:00, 29.03s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:55<00:00, 29.27s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:54<00:00, 29.12s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:53<00:00, 28.96s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:53<00:00, 28.98s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:55<00:00, 29.25s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:54<00:00, 29.10s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:55<00:00, 29.28s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:57<00:00, 29.52s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:57<00:00, 29.52s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:56<00:00, 29.36s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [02:56<00:00, 29.37s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:02<00:00, 30.44s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:16<00:00, 32.73s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.40s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.50s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.40s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:51<00:00, 38.63s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:48<00:00, 38.16s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.46s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.61s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.38s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.58s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.71s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:41<00:00, 36.91s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.52s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.47s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.78s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.57s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:37<00:00, 36.27s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:37<00:00, 36.27s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:37<00:00, 36.30s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:37<00:00, 36.24s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:37<00:00, 36.24s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:35<00:00, 35.92s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:36<00:00, 36.00s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.37s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:37<00:00, 36.17s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:36<00:00, 36.02s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:36<00:00, 36.07s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.59s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:41<00:00, 36.98s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:41<00:00, 36.96s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.67s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.76s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.69s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:48<00:00, 38.16s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.39s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.64s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:41<00:00, 36.90s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.60s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.72s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:38<00:00, 36.47s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:39<00:00, 36.64s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:33<00:00, 35.59s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.80s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.78s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:41<00:00, 36.89s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:41<00:00, 36.96s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.83s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.82s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.76s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:40<00:00, 36.70s/it]
# Processing Overlap Correction: 100%|█████████████| 3/3 [01:49<00:00, 36.54s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %%
# %load select_directory('src_ref')
src_ref = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\00_Raw_sorted\exp101"

# %%
# %load select_directory('dst_ref')
dst_ref = dst

# %%
mcpoc_correct_batch(src_ref, dst_ref, ref_sh_count = 9000, exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:43<00:00, 37.20s/it]
# Processing Overlap Correction: 100%|███████████| 12/12 [07:27<00:00, 37.29s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %% [markdown]
# ## Overlap Correction Exp103

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\00_Raw_sorted\exp103"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\01_Overlap_corrected\exp103"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 9000, exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:41<00:00, 37.00s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:42<00:00, 37.16s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:46<00:00, 37.70s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:48<00:00, 38.11s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:47<00:00, 37.85s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:47<00:00, 37.90s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:48<00:00, 38.05s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:49<00:00, 38.30s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:47<00:00, 37.95s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [00:37<00:00, 37.83s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %%
# %load select_directory('src_ref')
src_ref = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\00_Raw_sorted\exp101"

# %%
# %load select_directory('dst_ref')
dst_ref = dst

# %%
mcpoc_correct_batch(src_ref, dst_ref, ref_sh_count = 9000, exp_threshold= 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 6/6 [03:37<00:00, 36.30s/it]
# Processing Overlap Correction: 100%|███████████| 12/12 [07:17<00:00, 36.46s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []
