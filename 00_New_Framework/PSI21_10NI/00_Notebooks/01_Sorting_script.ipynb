# %% [markdown]
# # Image processing notebook: Sorting script or MCP with metadata.txt
#
#
# it is better to do it exp by exp
#
# The dst folder will have two numbers as identifiers at the beginning, they are in order according to the processing

# %%
import sys
sys.path.append(r'..\01_Functions')
from extra_functions import *

# %% [markdown]
# ### Fisrt folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI\100_raw\exp001"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\exp001"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|██████████████████████████████| 1/1 [31:40<00:00, 1900.42s/it]

# %% [markdown]
# ### Second folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI\100_raw\exp101"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\exp101"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|███████████████████████████████| 2/2 [05:28<00:00, 164.11s/it]

# %% [markdown]
# ### Third folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI\100_raw\exp102"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\exp102"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|███████████████████████████| 66/66 [2:23:06<00:00, 130.10s/it]

# %% [markdown]
# ### Fourth folder

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI\100_raw\exp103"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_10NI_updated_framework\exp103"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 100)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...: 100%|██████████████████████████████| 10/10 [13:24<00:00, 80.42s/it]
