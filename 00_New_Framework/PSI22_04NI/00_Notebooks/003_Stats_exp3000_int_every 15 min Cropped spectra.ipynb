# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]

add_to_dict(exp_param, ['threshold', 'use_ref', 'new_shape'], 
            [0, False, (256,256)])

# %%
exp_seq =  [outlier_removal,
            #binning_acquisitions,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            image_binning_dict
            #referencing_dict
           ]

# %% [markdown]
# #### for ECl results
# exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
#             stack_averaging,
#             scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
#             SBKG_correction_dict,
#             slice_values_dict]

# %% [markdown]
# ## Experiment pre oper

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000_chopped\pre_oper20C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\03_stats\exp3000_pre_oper"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'trans_pre_oper20C'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:12<00:00,  4.25s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:30<00:00, 30.79s/it]
# Processing Filetring : 100%|██████████████████| 15/15 [33:21<00:00, 133.44s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:29<00:00, 29.40s/it]
# Processing Scrubbing Correction: 100%|█████████| 15/15 [00:23<00:00,  1.57s/it]
# Processing SBKG Correction: 100%|██████████████| 15/15 [06:28<00:00, 25.91s/it]
# Binning arrays in dictionary: 100%|████████████| 15/15 [00:07<00:00,  1.91it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|██████████████████████████| 15/15 [01:05<00:00,  4.33s/it]
# Total time: 2565s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:32<00:00, 10.91s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:23<00:00, 23.79s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [12:59<00:00, 129.95s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:32<00:00, 32.39s/it]
# Processing Scrubbing Correction: 100%|███████████| 6/6 [00:06<00:00,  1.16s/it]
# Processing SBKG Correction: 100%|████████████████| 6/6 [02:25<00:00, 24.27s/it]
# Binning arrays in dictionary: 100%|██████████████| 6/6 [00:03<00:00,  1.97it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 6/6 [00:25<00:00,  4.29s/it]
# Total time: 1053s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:31<00:00, 10.57s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:06<00:00,  6.59s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [13:33<00:00, 135.53s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:33<00:00, 33.45s/it]
# Processing Scrubbing Correction: 100%|███████████| 6/6 [00:07<00:00,  1.19s/it]
# Processing SBKG Correction: 100%|████████████████| 6/6 [02:21<00:00, 23.65s/it]
# Binning arrays in dictionary: 100%|██████████████| 6/6 [00:03<00:00,  1.95it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 6/6 [00:25<00:00,  4.32s/it]
# Total time: 1066s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:29<00:00,  9.93s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:07<00:00,  7.92s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [14:07<00:00, 141.32s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:30<00:00, 30.81s/it]
# Processing Scrubbing Correction: 100%|███████████| 6/6 [00:06<00:00,  1.15s/it]
# Processing SBKG Correction: 100%|████████████████| 6/6 [02:23<00:00, 23.98s/it]
# Binning arrays in dictionary: 100%|██████████████| 6/6 [00:03<00:00,  1.96it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 6/6 [00:26<00:00,  4.41s/it]
# Total time: 1099s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:35<00:00, 11.70s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:05<00:00,  5.98s/it]
# Processing Filetring : 100%|████████████████████| 7/7 [15:33<00:00, 133.36s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:30<00:00, 30.73s/it]
# Processing Scrubbing Correction: 100%|███████████| 7/7 [00:08<00:00,  1.14s/it]
# Processing SBKG Correction: 100%|████████████████| 7/7 [02:48<00:00, 24.07s/it]
# Binning arrays in dictionary: 100%|██████████████| 7/7 [00:03<00:00,  1.95it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 7/7 [00:30<00:00,  4.32s/it]
# Total time: 1219s
