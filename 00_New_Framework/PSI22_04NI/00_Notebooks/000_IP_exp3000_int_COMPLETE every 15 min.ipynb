# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\02_empty_ref"

# %%
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\ref"

# %% [markdown]
# ## Uplod the reference folder
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp2000\00_empty_ref02"

ref_dict04 = read_saved_dict (ref_dir, proc_folder = ['10_pos04'])
# Out:
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  5.91it/s]

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]

add_to_dict(exp_param, ['threshold', 'frames_binning_factor', 'use_ref', 'new_shape', 'acquisitions_binning_factor'], 
            [0, 2, False, (256,256), 3])

# %%
exp_seq =  [outlier_removal,
            binning_acquisitions,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict,
            #referencing_dict
           ]

# %% [markdown]
# #### for ECl results
# exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
#             stack_averaging,
#             scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
#             SBKG_correction_dict,
#             slice_values_dict]

# %% [markdown]
# ## Experiment LP30 oper 20C Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3100_LP30_oper_20C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000\01_LP30_oper_20C_15min_avg"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'LP30_oper_20C_15_min_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.26it/s]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.25s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:10<00:00, 31.83s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.48s/it]
# Not enough acquisitions for binning, saving 01_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.69it/s]
# Not enough acquisitions for binning, saving 03_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.39s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.52it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.79it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.15it/s]
# Total time: 234s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.35s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.86s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:00<00:00, 40.09s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.38s/it]
# Not enough acquisitions for binning, saving 03_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.63it/s]
# Not enough acquisitions for binning, saving 05_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.53it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.32s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.57it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.53it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.23it/s]
# Total time: 302s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.32s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.47s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:02<00:00, 40.40s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.38s/it]
# Not enough acquisitions for binning, saving 05_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.66it/s]
# Not enough acquisitions for binning, saving 07_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.71it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:15<00:00,  7.98s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.52it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 11.02it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.24it/s]
# Total time: 294s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.27s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.32s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:01<00:00, 40.26s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.30s/it]
# Not enough acquisitions for binning, saving 07_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.69it/s]
# Not enough acquisitions for binning, saving 09_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.61it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.11s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.58it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 11.01it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.12it/s]
# Total time: 293s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.20s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.27s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:04<00:00, 40.71s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.60s/it]
# Not enough acquisitions for binning, saving 09_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.71it/s]
# Not enough acquisitions for binning, saving 11_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.72it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.09s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.58it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.89it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.20it/s]
# Total time: 295s

# %%
proc_folder = ['12_pos05']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.21s/it]
# Experiment 12_pos05 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.30s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:59<00:00, 39.88s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.61s/it]
# Not enough acquisitions for binning, saving 11_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.70it/s]
# Not enough acquisitions for binning, saving 13_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.73it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.21s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.49it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 11.03it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.23it/s]
# Total time: 291s

# %%
proc_folder = ['14_pos06']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.46s/it]
# Experiment 14_pos06 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.42s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:59<00:00, 39.98s/it]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:32<00:00, 16.44s/it]
# Not enough acquisitions for binning, saving 13_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.67it/s]
# Not enough acquisitions for binning, saving 15_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.69it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.12s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.53it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.13it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.23it/s]
# Total time: 309s

# %%
proc_folder = ['16_pos07']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.38s/it]
# Experiment 16_pos07 in process...
# Processing Filetring : 100%|█████████████████████| 2/2 [00:16<00:00,  8.37s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:55<00:00, 49.23s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:26<00:00, 26.48s/it]
# Not enough acquisitions for binning, saving 15_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.67it/s]
# Not enough acquisitions for binning, saving 17_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.64it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.05s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.56it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.37it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:02<00:00,  1.10s/it]
# Total time: 366s

# %%
proc_folder = ['18_pos08']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:06<00:00,  2.25s/it]
# Experiment 18_pos08 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.33s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:37<00:00, 46.19s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.92s/it]
# Not enough acquisitions for binning, saving 17_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.69it/s]
# Not enough acquisitions for binning, saving 19_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.69it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.26s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.42it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.22it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.23it/s]
# Total time: 333s

# %%
proc_folder = ['20_pos09']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.40s/it]
# Experiment 20_pos09 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.32s/it]
# Processing Filetring : 100%|█████████████████████| 7/7 [04:40<00:00, 40.06s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.63s/it]
# Not enough acquisitions for binning, saving 19_ob as a single acquisition
# Extra (final) acquisition left out due to binning factor
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.70it/s]
# Not enough acquisitions for binning, saving 21_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.69it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.18s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.55it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.90it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.19it/s]
# Total time: 332s

# %% [markdown]
# ## Experiment LP30 oper m25C Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3500_LP30_oper_m25C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000\08_LP30_oper_m25C_15_min"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'LP30_oper_m25C_15_min_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:07<00:00,  2.41s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.35s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:56<00:00, 39.38s/it]
# Processing Filetring : 100%|█████████████████████| 7/7 [01:54<00:00, 16.35s/it]
# Not enough acquisitions for binning, saving 01_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.71it/s]
# Extra (final) acquisition left out due to binning factor
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.69it/s]
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.58it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.14s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.56it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.91it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.28it/s]
# Total time: 399s
