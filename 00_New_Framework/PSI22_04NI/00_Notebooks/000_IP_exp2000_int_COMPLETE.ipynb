# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ###  Process the reference folder (if not done before). Otherwise go to Chapter 2
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\02_empty_ref"

# %%
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\ref"

# %% [markdown]
# ### Full Ref02 processing

# %%
stack_dict = prep_stack_dict(ref_dir)

# %%
ref_param = {}
nca = [0,0,0,0]

add_to_dict(ref_param, ['threshold', 'frames_binning_factor', 'new_shape'],  [0, 2, (256,256)])

# %%
ref_seq =  [outlier_removal,
            stack_averaging,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict
            ]

# %%
img_name = 'ref02_pristine_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(ref_dir + '/pos_00.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(ref_dir + '/pos_01.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(ref_dir + '/pos_02.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(ref_dir + '/pos_03.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(ref_dir + '/pos_04.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)

# %% [markdown]
# ## Process the reference folder (if not done before)
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\ref"
ref_dict00 = read_saved_dict (ref_dir, proc_folder = ['02_pos00'])
ref_dict01 = read_saved_dict (ref_dir, proc_folder = ['04_pos01'])
ref_dict02 = read_saved_dict (ref_dir, proc_folder = ['06_pos02'])
ref_dict03 = read_saved_dict (ref_dir, proc_folder = ['08_pos03'])
ref_dict04 = read_saved_dict (ref_dir, proc_folder = ['10_pos04'])
# Out:
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  7.61it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  8.63it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  7.61it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  8.63it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  8.17it/s]

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]

add_to_dict(exp_param, ['threshold', 'frames_binning_factor', 'use_ref', 'new_shape'], [0, 2, False, (256,256)])

# %%
exp_seq =  [outlier_removal,
            stack_averaging,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict,
            #referencing_dict
           ]

# %% [markdown]
# #### for ECl results
# exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
#             stack_averaging,
#             scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
#             SBKG_correction_dict,
#             slice_values_dict]

# %% [markdown]
# ## Experiment ref02 Processing

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\00_empty_ref02"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp2000\00_empty_ref02"

# %%
img_name = 'ref02_empty_int'

# %% [markdown]
# ### Full Processing

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:12<00:00,  4.02s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.85s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:18<00:00, 33.03s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:34<00:00, 34.64s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.74it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.21s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.41it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.17it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.28it/s]
# Total time: 277s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:21<00:00,  7.24s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:07<00:00,  8.00s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:39<00:00, 36.53s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.29s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.60it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.03s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.48it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.16it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.21it/s]
# Total time: 282s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:10<00:00,  3.41s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.21s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:49<00:00, 38.23s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.15s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.15s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.53it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00,  9.81it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.28it/s]
# Total time: 279s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:12<00:00,  4.06s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.06s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:16<00:00, 32.82s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.09s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.71it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.34s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.41it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00,  9.87it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.16it/s]
# Total time: 249s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:11<00:00,  3.96s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.04s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:15<00:00, 32.66s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.25s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.37it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.18s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.42it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.02it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.29it/s]
# Total time: 247s

# %% [markdown]
# ## Experiment LP30 Degraded Processing

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\01_LP30_deg"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp2000\00_LP30_deg"

# %%
img_name = 'LP30_deg_int'

# %% [markdown]
# ### Full Processing

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict00])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:10<00:00,  3.46s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.63s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:04<00:00, 40.76s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.61s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.35it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.56s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.24it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.11it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.21it/s]
# Total time: 305s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict01])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:09<00:00,  3.06s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.05s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:53<00:00, 38.95s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.69s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.41it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.39s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.47it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.99it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.12it/s]
# Total time: 283s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:09<00:00,  3.00s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.52s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:11<00:00, 41.90s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.06s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.48it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.79s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.42it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.02it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.23it/s]
# Total time: 301s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict03])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:08<00:00,  2.87s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:07<00:00,  7.98s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:01<00:00, 40.31s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.10s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.66s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.43it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.91it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.17it/s]
# Total time: 290s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict04])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:08<00:00,  2.98s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:07<00:00,  7.78s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:02<00:00, 40.35s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.24s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.66it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.67s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.53it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.91it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# Total time: 290s

# %% [markdown]
# ## Experiment LP40 Degraded Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\02_LP40_deg"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp2000\00_LP40_deg"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'LP40_deg_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict00])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:12<00:00,  4.08s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.93s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:05<00:00, 40.95s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.48s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.66it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.57s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.47it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.97it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.28it/s]
# Total time: 308s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:12<00:00,  4.07s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.08s/it]
# Processing Filetring : 100%|█████████████████████| 7/7 [05:01<00:00, 43.02s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:23<00:00, 23.99s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.14s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.53it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.93it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.19it/s]
# Total time: 359s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:13<00:00,  4.62s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.16s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:43<00:00, 47.19s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.20s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.31s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.52it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.16it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.20it/s]
# Total time: 337s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:10<00:00,  3.55s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.25s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:05<00:00, 40.95s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.29s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.73it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.16s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.50it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.23it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.23it/s]
# Total time: 296s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:11<00:00,  3.99s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.10s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:06<00:00, 41.16s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.70s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.71it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.56s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.42it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.19it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.24it/s]
# Total time: 299s

# %% [markdown]
# ## Experiment BB_ref_nosample Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\03_bbref_nosample"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp2000\01_bbref_nosample"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'bbref_nosample_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict00])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:14<00:00,  4.76s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.70s/it]
# Processing Filetring : 100%|█████████████████████| 7/7 [03:01<00:00, 25.91s/it]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:37<00:00, 18.78s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.60it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.45s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.37it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 12.01it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.08it/s]
# Total time: 266s
