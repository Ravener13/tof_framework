# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3100_LP30_oper_20C"

# %%
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000\00_Operando_wref_discharged"

# %% [markdown]
# ## Uplod the reference folder
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
ref_param = {}
nca = [0,0,0,0]

add_to_dict(ref_param, ['threshold', 'frames_binning_factor', 'new_shape', 'ws_filter_size'], [0, 2, (256,256), 5])

# %%
ref_seq =  [outlier_removal,
            stack_averaging,
            scrubbing_correction_dict,
            ws_filter,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict
            ]

# %%
img_name = 'discharged_20_pos09'
proc_folder = ['20_pos09']
BB_mask = get_img(ref_dir + '/pos_04.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

ref_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.02s/it]
# Experiment 20_pos09 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.02s/it]
# Processing Filetring : 100%|█████████████████████| 7/7 [04:31<00:00, 38.78s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.11s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.58it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:06<00:00,  6.58s/it]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.16s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.48it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.97it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.21it/s]
# Total time: 328s

# %%
#ref_dict04 = read_saved_dict (ref_dir, proc_folder = ['20_pos09'])

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]

add_to_dict(exp_param, ['threshold', 'frames_binning_factor', 'use_ref', 'new_shape', 'ws_filter_size', 'acquisitions_binning_factor'], 
            [0, 2, True, (256,256),5, 3])

# %%
exp_seq =  [outlier_removal,
            binning_acquisitions,
            scrubbing_correction_dict,
            ws_filter,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict,
            referencing_dict,
           ]

# %% [markdown]
# #### for ECl results
# exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
#             stack_averaging,
#             scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
#             SBKG_correction_dict,
#             slice_values_dict]

# %% [markdown]
# ## Experiment LP30 oper 20C Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3100_LP30_oper_20C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000\00_Operando_wref_discharged"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'oper_20C_15_min_trans'
add_to_dict(exp_param,['ref_dict'], [ref_dict])

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.04s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.05s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:56<00:00, 39.39s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.13s/it]
# Not enough acquisitions for binning, saving 01_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.65it/s]
# Not enough acquisitions for binning, saving 03_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.69it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.59s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:15<00:00,  7.92s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.49it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00,  9.93it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 61.48it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.10it/s]
# Total time: 307s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.04it/s]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.44s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:57<00:00, 39.56s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.44s/it]
# Not enough acquisitions for binning, saving 03_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.64it/s]
# Not enough acquisitions for binning, saving 05_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.67it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.68s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.11s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.46it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 11.04it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 65.37it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.11it/s]
# Total time: 301s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.04it/s]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.42s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:58<00:00, 39.79s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.21s/it]
# Not enough acquisitions for binning, saving 05_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.66it/s]
# Not enough acquisitions for binning, saving 07_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.68it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.63s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.38s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.32it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.89it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 65.59it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.20it/s]
# Total time: 303s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.32s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.40s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:57<00:00, 39.62s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.35s/it]
# Not enough acquisitions for binning, saving 07_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.51it/s]
# Not enough acquisitions for binning, saving 09_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.28it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.67s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.47s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.44it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.93it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 61.38it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.18it/s]
# Total time: 304s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.01s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.15s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:59<00:00, 39.86s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.23s/it]
# Not enough acquisitions for binning, saving 09_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.67it/s]
# Not enough acquisitions for binning, saving 11_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.72it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.59s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:15<00:00,  7.99s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.59it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.91it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 65.28it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.14it/s]
# Total time: 302s

# %%
proc_folder = ['12_pos05']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.03it/s]
# Experiment 12_pos05 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.11s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:55<00:00, 39.22s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.25s/it]
# Not enough acquisitions for binning, saving 11_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.60it/s]
# Not enough acquisitions for binning, saving 13_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.52it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.69s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.00s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.56it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.91it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 65.42it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.19it/s]
# Total time: 299s

# %%
proc_folder = ['14_pos06']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.10s/it]
# Experiment 14_pos06 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.31s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:57<00:00, 39.55s/it]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:34<00:00, 17.12s/it]
# Not enough acquisitions for binning, saving 13_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.66it/s]
# Not enough acquisitions for binning, saving 15_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.65it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.64s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:15<00:00,  7.97s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.49it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.91it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 65.27it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.12it/s]
# Total time: 319s

# %%
proc_folder = ['16_pos07']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:21<00:00,  7.07s/it]
# Experiment 16_pos07 in process...
# Processing Filetring : 100%|█████████████████████| 2/2 [00:16<00:00,  8.28s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [05:42<00:00, 57.15s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.10s/it]
# Not enough acquisitions for binning, saving 15_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.68it/s]
# Not enough acquisitions for binning, saving 17_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.66it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.63s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.26s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.42it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.55it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 65.84it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.16it/s]
# Total time: 436s

# %%
proc_folder = ['18_pos08']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:11<00:00,  3.78s/it]
# Experiment 18_pos08 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.23s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:06<00:00, 41.17s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.34s/it]
# Not enough acquisitions for binning, saving 17_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.66it/s]
# Not enough acquisitions for binning, saving 19_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.65it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.61s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:16<00:00,  8.03s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.47it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 10.83it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 65.35it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.24it/s]
# Total time: 319s

# %%
proc_folder = ['20_pos09']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.16s/it]
# Experiment 20_pos09 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.24s/it]
# Processing Filetring : 100%|█████████████████████| 7/7 [04:35<00:00, 39.41s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.53s/it]
# Not enough acquisitions for binning, saving 19_ob as a single acquisition
# Extra (final) acquisition left out due to binning factor
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:02<00:00,  2.71it/s]
# Not enough acquisitions for binning, saving 21_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:00<00:00,  2.62it/s]
# Processing Filetring : 100%|█████████████████████| 2/2 [00:13<00:00,  6.61s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:15<00:00,  7.95s/it]
# Processing Binning Frames: 100%|█████████████████| 2/2 [00:00<00:00,  2.56it/s]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00, 11.02it/s]
# Processing Referencing Correction: 100%|█████████| 2/2 [00:00<00:00, 63.94it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:01<00:00,  1.28it/s]
# Total time: 340s

# %% [markdown]
# ## Experiment LP30 oper m25C Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3500_LP30_oper_m25C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000\08_LP30_oper_m25C_15_min"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'LP30_oper_m25C_15_min_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
