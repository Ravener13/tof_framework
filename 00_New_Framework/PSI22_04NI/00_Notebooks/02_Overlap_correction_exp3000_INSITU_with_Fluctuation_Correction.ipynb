# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod_IMAT22 import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3100_LP30_oper_20C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3100_LP30_oper_20C"

# %%
# %load select_directory('info')
info = r"J:\700 Campaigns - internal\2022\PSI22_04NI\exp_times.txt"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To get a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.
#
# #### binning refers to an average of a specific amount of images (x direction -> ToF direction)

# %% [markdown]
# ## Opeando 20C

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|████████████| 1/1 [01:57<00:00, 117.82s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [13:29<00:00, 134.91s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:24<00:00, 144.73s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [14:07<00:00, 141.26s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:58<00:00, 118.16s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:56<00:00, 119.46s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:59<00:00, 119.07s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [12:43<00:00, 127.33s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:17<00:00, 137.26s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [13:45<00:00, 137.59s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:52<00:00, 112.22s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:11<00:00, 111.96s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.53s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:09<00:00, 111.67s/it]
# Processing Overlap Correction: 100%|████████████| 2/2 [03:38<00:00, 109.33s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:09<00:00, 111.53s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:51<00:00, 111.25s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:35<00:00, 115.98s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:00<00:00, 120.63s/it]
# Processing Overlap Correction: 100%|████████████| 7/7 [13:49<00:00, 118.54s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:52<00:00, 112.30s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %% [markdown]
# ## Opeando m25C

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3500_LP30_oper_m25C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3500_LP30_oper_m25C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.02s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:00<00:00, 110.11s/it]
# Processing Overlap Correction: 100%|████████████| 9/9 [16:26<00:00, 109.59s/it]
# Experiments not processed due to low counts (counts threshold) are:  []
