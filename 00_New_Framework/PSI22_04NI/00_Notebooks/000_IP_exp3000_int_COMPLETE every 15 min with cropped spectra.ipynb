# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
#ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\02_empty_ref"

# %%
#dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\ref"

# %% [markdown]
# ## Uplod the reference folder
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp2000\00_empty_ref02"

ref_dict04 = read_saved_dict (ref_dir, proc_folder = ['10_pos04'])
# Out:
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  2.26it/s]

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]

add_to_dict(exp_param, ['threshold', 'use_ref', 'new_shape', 'acquisitions_binning_factor'], 
            [0, False, (256,256), 3])

# %%
exp_seq =  [outlier_removal,
            binning_acquisitions,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            image_binning_dict
            #referencing_dict
           ]

# %% [markdown]
# #### for ECl results
# exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
#             stack_averaging,
#             scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
#             SBKG_correction_dict,
#             slice_values_dict]

# %% [markdown]
# ## Experiment LP30 oper 20C Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000_chopped\exp3100_LP30_oper_20C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000_chopped\01_LP30_oper_20C_15min_avg"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'LP30_oper_20C_15_min_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:26<00:00,  8.80s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:30<00:00, 30.80s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [13:47<00:00, 137.90s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:42<00:00, 42.10s/it]
# Not enough acquisitions for binning, saving 01_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:06<00:00,  1.01s/it]
# Not enough acquisitions for binning, saving 03_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.03s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:49<00:00, 24.53s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.96it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:09<00:00,  4.78s/it]
# Total time: 997s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:22<00:00,  7.60s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:07<00:00,  7.40s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [14:05<00:00, 140.84s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:41<00:00, 41.18s/it]
# Not enough acquisitions for binning, saving 03_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.03it/s]
# Not enough acquisitions for binning, saving 05_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.05s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:50<00:00, 25.08s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.99it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:09<00:00,  4.68s/it]
# Total time: 988s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:19<00:00,  6.49s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:06<00:00,  6.75s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [15:34<00:00, 155.70s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [01:08<00:00, 68.86s/it]
# Not enough acquisitions for binning, saving 05_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.03it/s]
# Not enough acquisitions for binning, saving 07_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.04s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:49<00:00, 24.62s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.97it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:11<00:00,  5.96s/it]
# Total time: 1102s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:33<00:00, 11.03s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:06<00:00,  6.14s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [15:53<00:00, 158.91s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:34<00:00, 34.69s/it]
# Not enough acquisitions for binning, saving 07_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.04it/s]
# Not enough acquisitions for binning, saving 09_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.04s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:51<00:00, 25.73s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.96it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:11<00:00,  5.91s/it]
# Total time: 1102s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:21<00:00,  7.17s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:06<00:00,  6.20s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [13:44<00:00, 137.35s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:34<00:00, 34.10s/it]
# Not enough acquisitions for binning, saving 09_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.05it/s]
# Not enough acquisitions for binning, saving 11_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.02s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:50<00:00, 25.30s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.93it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:12<00:00,  6.11s/it]
# Total time: 961s

# %%
proc_folder = ['12_pos05']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:20<00:00,  6.80s/it]
# Experiment 12_pos05 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:05<00:00,  5.60s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [13:59<00:00, 139.84s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:36<00:00, 36.06s/it]
# Not enough acquisitions for binning, saving 11_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.03it/s]
# Not enough acquisitions for binning, saving 13_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.04s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:49<00:00, 24.97s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.98it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:10<00:00,  5.08s/it]
# Total time: 973s

# %%
proc_folder = ['14_pos06']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:51<00:00, 17.25s/it]
# Experiment 14_pos06 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:06<00:00,  6.29s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [14:42<00:00, 147.15s/it]
# Processing Filetring : 100%|█████████████████████| 2/2 [01:02<00:00, 31.08s/it]
# Not enough acquisitions for binning, saving 13_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.06it/s]
# Not enough acquisitions for binning, saving 15_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.01s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:46<00:00, 23.37s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00,  2.02it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:08<00:00,  4.32s/it]
# Total time: 1071s

# %%
proc_folder = ['16_pos07']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:23<00:00,  7.87s/it]
# Experiment 16_pos07 in process...
# Processing Filetring : 100%|█████████████████████| 2/2 [00:12<00:00,  6.02s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [12:53<00:00, 128.84s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:30<00:00, 30.54s/it]
# Not enough acquisitions for binning, saving 15_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.07it/s]
# Not enough acquisitions for binning, saving 17_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:01<00:00,  1.01it/s]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:46<00:00, 23.35s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.98it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:08<00:00,  4.31s/it]
# Total time: 907s

# %%
proc_folder = ['18_pos08']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:21<00:00,  7.15s/it]
# Experiment 18_pos08 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:06<00:00,  6.42s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [12:48<00:00, 128.01s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:28<00:00, 28.88s/it]
# Not enough acquisitions for binning, saving 17_ob as a single acquisition
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.03it/s]
# Not enough acquisitions for binning, saving 19_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.10s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:51<00:00, 25.70s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:01<00:00,  1.82it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:09<00:00,  4.60s/it]
# Total time: 898s

# %%
proc_folder = ['20_pos09']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:26<00:00,  8.86s/it]
# Experiment 20_pos09 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:05<00:00,  5.81s/it]
# Processing Filetring : 100%|████████████████████| 7/7 [18:29<00:00, 158.51s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:44<00:00, 44.96s/it]
# Not enough acquisitions for binning, saving 19_ob as a single acquisition
# Extra (final) acquisition left out due to binning factor
# Processing Binning Acquisitions: 100%|███████████| 6/6 [00:05<00:00,  1.04it/s]
# Not enough acquisitions for binning, saving 21_ob as a single acquisition
# Processing Scrubbing Correction: 100%|███████████| 2/2 [00:02<00:00,  1.02s/it]
# Processing SBKG Correction: 100%|████████████████| 2/2 [00:49<00:00, 24.75s/it]
# Binning arrays in dictionary: 100%|██████████████| 2/2 [00:00<00:00,  2.04it/s]
# Saving images as a time series of acquisitions
# Writing Images: 100%|████████████████████████████| 2/2 [00:10<00:00,  5.44s/it]
# Total time: 1260s

# %% [markdown]
# ## Experiment ref02 (here it changes because we do not need 15 min)

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000_chopped\ref02"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000_chopped\ref02"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
exp_param = {}
nca = [0,0,0,0]

add_to_dict(exp_param, ['threshold', 'use_ref', 'new_shape'], [0, False, (256,256)])

exp_seq =  [outlier_removal,
            stack_averaging,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict
            #referencing_dict
           ]

# %%
img_name = 'ref02'

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:32<00:00, 10.84s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:40<00:00, 40.63s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [10:19<00:00, 103.22s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:30<00:00, 30.05s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:01<00:00,  1.01s/it]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:23<00:00, 23.04s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:01<00:00,  1.26s/it]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00,  2.00it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:04<00:00,  4.21s/it]
# Total time: 763s

# %% [markdown]
# ## Experiment pre oper

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000_chopped\pre_oper20C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000_chopped\pre_oper20C"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'pre_oper20C'

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:30<00:00, 10.01s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:29<00:00, 29.65s/it]
# Processing Filetring : 100%|████████████████████| 7/7 [15:20<00:00, 131.45s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:30<00:00, 30.06s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:01<00:00,  1.03s/it]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:23<00:00, 23.56s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:01<00:00,  1.29s/it]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00,  1.99it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:04<00:00,  4.13s/it]
# Total time: 1052s

# %% [markdown]
# ## Experiment After oper

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000_chopped\after_oper20C"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp3000_chopped\after_oper20C"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'after_oper20C'

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:25<00:00,  8.62s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 2/2 [01:00<00:00, 30.15s/it]
# Processing Filetring : 100%|████████████████████| 6/6 [13:10<00:00, 131.71s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:29<00:00, 29.35s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:01<00:00,  1.05s/it]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:23<00:00, 23.51s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:01<00:00,  1.28s/it]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00,  2.07it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:04<00:00,  4.40s/it]
# Total time: 947s
