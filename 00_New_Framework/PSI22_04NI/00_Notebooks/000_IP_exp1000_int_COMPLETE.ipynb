# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\02_empty_ref"

# %%
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\ref"

# %% [markdown]
# ### Full Ref02 processing

# %%
stack_dict = prep_stack_dict(ref_dir)

# %%
ref_param = {}
nca = [0,0,0,0]

add_to_dict(ref_param, ['threshold', 'frames_binning_factor', 'new_shape'],  [0, 2, (256,256)])

# %%
ref_seq =  [outlier_removal,
            stack_averaging,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict
            ]

# %%
img_name = 'ref02_pristine_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(ref_dir + '/pos_00.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:01<00:00,  1.51it/s]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.62s/it]
# Processing Filetring : 100%|█████████████████████| 3/3 [01:35<00:00, 31.89s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.34s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.73it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.17s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.46it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00,  8.90it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.28it/s]
# Total time: 145s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(ref_dir + '/pos_01.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.17it/s]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.41s/it]
# Processing Filetring : 100%|█████████████████████| 4/4 [02:10<00:00, 32.67s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.17s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.54s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.54it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.00it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.35it/s]
# Total time: 163s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(ref_dir + '/pos_02.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.24s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.13s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:14<00:00, 32.43s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.66s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.73it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.28s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.48it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.94it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.06it/s]
# Total time: 238s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(ref_dir + '/pos_03.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.23s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.15s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [03:16<00:00, 32.69s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.01s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.72it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.04s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.53it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.91it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.31it/s]
# Total time: 239s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(ref_dir + '/pos_04.fits')
add_to_dict(ref_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (ref_dir, dst_dir, proc_folder = proc_folder, sequence = ref_seq, 
                 proc_parameters = ref_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.01it/s]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.31s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [02:41<00:00, 32.23s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.10s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.59it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:07<00:00,  7.94s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.31it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.02it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.34it/s]
# Total time: 202s

# %% [markdown]
# ## Process the reference folder (if not done before)
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\ref"
ref_dict00 = read_saved_dict (ref_dir, proc_folder = ['02_pos00'])
ref_dict01 = read_saved_dict (ref_dir, proc_folder = ['04_pos01'])
ref_dict02 = read_saved_dict (ref_dir, proc_folder = ['06_pos02'])
ref_dict03 = read_saved_dict (ref_dir, proc_folder = ['08_pos03'])
ref_dict04 = read_saved_dict (ref_dir, proc_folder = ['10_pos04'])
# Out:
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  5.43it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  4.27it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  3.59it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  4.49it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  5.41it/s]

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]

add_to_dict(exp_param, ['threshold', 'frames_binning_factor', 'use_ref', 'new_shape'], [0, 2, False, (256,256)])

# %%
exp_seq =  [outlier_removal,
            stack_averaging,
            scrubbing_correction_dict,
            SBKG_correction_dict,
            binning_frames,
            image_binning_dict,
            #referencing_dict
           ]

# %% [markdown]
# #### for ECl results
# exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
#             stack_averaging,
#             scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
#             SBKG_correction_dict,
#             slice_values_dict]

# %% [markdown]
# ## Experiment LP30 Pristine Processing

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\00_LP30_pristine"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\00_LP30_pristine"

# %%
img_name = 'LP30_pristine_int'

# %% [markdown]
# ### Full Processing

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict00])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.34it/s]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.15s/it]
# Processing Filetring : 100%|█████████████████████| 4/4 [02:41<00:00, 40.45s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.32s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.62it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.27s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.56it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.01it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.20it/s]
# Total time: 212s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict01])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.16it/s]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.05s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [03:17<00:00, 39.57s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:16<00:00, 16.71s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.10s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.48it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.90it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.22it/s]
# Total time: 238s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.46s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.17s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:52<00:00, 48.82s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.90s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.58it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.14s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.41it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.95it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.27it/s]
# Total time: 338s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict03])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.38s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.20s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:37<00:00, 46.17s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:17<00:00, 17.79s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.75it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.37s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.47it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00,  8.80it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.23it/s]
# Total time: 321s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict04])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.32s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.13s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:09<00:00, 41.51s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.19s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.18s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.48it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.89it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.26it/s]
# Total time: 293s

# %% [markdown]
# ## Experiment LP40 Pristine Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\01_LP40_pristine"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\000_exp1000\00_LP40_pristine"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
img_name = 'LP40_pristine_int'

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict00])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = img_name, save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:16<00:00,  5.57s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.84s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:19<00:00, 43.32s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.77s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.75it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:07<00:00,  7.96s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.55it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.11it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.21it/s]
# Total time: 331s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:15<00:00,  5.05s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.00s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:12<00:00, 42.05s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.36s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.15s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.60it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.91it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.18it/s]
# Total time: 308s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:14<00:00,  4.68s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:07<00:00,  7.91s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [03:36<00:00, 43.31s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.18s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.65it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.04s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.53it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.89it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.29it/s]
# Total time: 272s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:17<00:00,  5.69s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:08<00:00,  8.16s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [04:17<00:00, 42.87s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.15s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.71it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:08<00:00,  8.21s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.53it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 10.88it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.26it/s]
# Total time: 316s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:13<00:00,  4.49s/it]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:07<00:00,  7.98s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [03:33<00:00, 42.61s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.39s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  2.72it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:07<00:00,  7.97s/it]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.54it/s]
# Binning arrays in dictionary: 100%|██████████████| 1/1 [00:00<00:00, 11.94it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  1.24it/s]
# Total time: 267s
