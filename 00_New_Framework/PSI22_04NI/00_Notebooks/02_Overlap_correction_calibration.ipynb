# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod_IMAT22 import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp5000\exp5000_aluvette_20C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\calibration\aluminum"

# %%
# %load select_directory('info')
info = r"J:\700 Campaigns - internal\2022\PSI22_04NI\exp_times.txt"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To get a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.
#
# #### binning refers to an average of a specific amount of images (x direction -> ToF direction)

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 1, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:19<00:00, 79.37s/it]
# Processing Overlap Correction: 100%|███████████| 12/12 [16:01<00:00, 80.15s/it]
# Processing Overlap Correction: 100%|█████████████| 2/2 [02:38<00:00, 79.14s/it]
# Processing Overlap Correction: 100%|███████████| 13/13 [17:50<00:00, 82.38s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:32<00:00, 92.37s/it]
# Processing Overlap Correction: 100%|███████████| 12/12 [12:27<00:00, 62.33s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:21<00:00, 81.83s/it]
# Processing Overlap Correction: 100%|███████████| 12/12 [16:01<00:00, 80.10s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:18<00:00, 78.99s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"H:\700 Campaigns - internal\2022\PSI22_04NI\arch\Raw_images\Calibration_short"

# %%
# %load select_directory('dst')
dst = r"H:\700 Campaigns - internal\2022\PSI22_04NI\temp\Calibration_overlap_corr\Fe_short"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 0 , binning = 1, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|████████████| 1/1 [12:07<00:00, 727.57s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [11:33<00:00, 693.30s/it]
# Experiments not processed due to low counts (counts threshold) are:  []
