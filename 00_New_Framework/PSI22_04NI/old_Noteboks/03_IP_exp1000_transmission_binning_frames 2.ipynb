# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - exp 1XX acquisition 00

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000_bin20\00_LP30_pristine"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp1000_bin20\00_LP30_pristine"

# %% [markdown]
# ### Check folders to process

# %%
stack_dict = prep_stack_dict(src_dir)
for key in stack_dict.keys():
    print(key)
# Out:
# 01_ob
# 02_pos00
# 03_ob
# 04_pos01
# 05_ob
# 06_pos02
# 07_ob
# 08_pos03
# 09_ob
# 10_pos04
# 11_ob

# %% [markdown]
# ## Process the reference folder (if not done before)
# In case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000\00_empty_ref02"
ref_dict00 = read_saved_dict (ref_dir, proc_folder = ['02_pos00'])
ref_dict01 = read_saved_dict (ref_dir, proc_folder = ['04_pos01'])
ref_dict02 = read_saved_dict (ref_dir, proc_folder = ['06_pos02'])
ref_dict03 = read_saved_dict (ref_dir, proc_folder = ['08_pos03'])
ref_dict04 = read_saved_dict (ref_dir, proc_folder = ['10_pos04'])

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]
#HE_LE = (True, [15,30],[30,50])

add_to_dict(exp_param, ['threshold', 'nca', 'use_ref', 'ws_filter_size'], [0, nca, False, 3])
add_to_dict(exp_param, ['end_slice'], [77])

# %%
exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
            stack_averaging,
            scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
            SBKG_correction_dict,
            TFC_correction_dict,
            slice_values_dict]

# %% [markdown]
# ## Experiment LP30 Pristine Processing

# %% [markdown]
# ### Full Processing

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict00])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:29<00:00,  9.78s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [01:27<00:00, 87.86s/it]
# Processing Filetring : 100%|█████████████████████| 4/4 [04:51<00:00, 72.94s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:59<00:00, 59.11s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.23it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.63s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  9.01it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.95s/it]
# Total time: 489s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict01])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:07<00:00,  2.40s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.13s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [02:49<00:00, 33.84s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.47s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.39it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.45s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.18it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 124.83it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.14s/it]
# Total time: 216s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.27s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.14s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:35<00:00, 25.86s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.59s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.44it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.29s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.29it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 497.49it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.19s/it]
# Total time: 200s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.37s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.15s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:32<00:00, 25.34s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.73s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.19it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:05<00:00,  5.15s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  7.13it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 124.83it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:18<00:00, 18.07s/it]
# Total time: 205s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.45it/s]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.11s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:26<00:00, 24.43s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:25<00:00, 25.04s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.28it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.27s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.28it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.18s/it]
# Total time: 195s

# %% [markdown]
# ## Experiment LP40 Pristine Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000_bin20\01_LP40_pristine"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp1000_bin20\01_LP40_pristine"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.46s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.54s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:22<00:00, 23.67s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:25<00:00, 25.44s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.21it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.55s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.28it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.28s/it]
# Total time: 211s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.46s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.13s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:49<00:00, 28.28s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:31<00:00, 31.47s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.23it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.33s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.11it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:12<00:00, 12.13s/it]
# Total time: 227s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:07<00:00,  2.33s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.05s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [02:08<00:00, 25.74s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.01s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.51it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.31s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  7.56it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:14<00:00, 14.90s/it]
# Total time: 179s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:05<00:00,  1.74s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.16s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:31<00:00, 25.31s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:21<00:00, 21.72s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  4.13it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:05<00:00,  5.98s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  7.65it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:19<00:00, 19.63s/it]
# Total time: 211s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
#add_to_dict(exp_param,['BB_mask', 'ref_dict'], [BB_mask, ref_dict02])
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_pristine_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:01<00:00,  1.74it/s]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.13s/it]
# Processing Filetring : 100%|█████████████████████| 5/5 [02:09<00:00, 25.89s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.86s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  4.96it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.53s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  9.02it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 124.79it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.05s/it]
# Total time: 172s

# %% [markdown]
# ## Experiment Empty Ref 01 Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\02_empty_ref"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp1000\02_empty_ref"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref01_intensity', save = True)

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref01_intensity', save = True)

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref01_intensity', save = True)

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref01_intensity', save = True)

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref01_intensity', save = True)
