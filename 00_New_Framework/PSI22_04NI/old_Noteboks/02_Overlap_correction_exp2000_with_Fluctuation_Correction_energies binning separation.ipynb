# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod_IMAT22 import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp2000\exp2000_empty_ref02"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000_bin100\00_empty_ref02"

# %%
# %load select_directory('info')
info = r"J:\700 Campaigns - internal\2022\PSI22_04NI\exp_times.txt"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To get a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.
#
# #### binning refers to an average of a specific amount of images (x direction -> ToF direction)

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|████████████| 1/1 [02:05<00:00, 125.86s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [12:30<00:00, 125.04s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:06<00:00, 126.45s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [12:28<00:00, 124.74s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:04<00:00, 124.61s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [13:00<00:00, 130.10s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:29<00:00, 149.01s/it]
# Processing Overlap Correction: 100%|████████████| 7/7 [15:15<00:00, 130.80s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:03<00:00, 123.98s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:56<00:00, 119.42s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:28<00:00, 88.24s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp2000\exp2100_LP30_deg"

# %%
# %load select_directory('dst')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp2000\exp2100_LP30_deg"
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000_bin100\01_LP30_deg"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 100, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:28<00:00, 88.55s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [08:51<00:00, 88.58s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:28<00:00, 88.07s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [08:56<00:00, 89.37s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:29<00:00, 89.12s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [10:31<00:00, 105.20s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:29<00:00, 89.48s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [08:53<00:00, 88.99s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:27<00:00, 87.89s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [08:51<00:00, 88.63s/it]
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:28<00:00, 88.31s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp2000\exp2200_LP40_deg"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000_bin20\02_LP40_deg"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 20, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|████████████| 1/1 [02:26<00:00, 146.17s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [14:14<00:00, 142.34s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:26<00:00, 146.42s/it]
# Processing Overlap Correction: 100%|████████████| 7/7 [16:55<00:00, 145.08s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:25<00:00, 145.40s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [14:30<00:00, 145.16s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:27<00:00, 147.89s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [15:38<00:00, 156.37s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:23<00:00, 143.73s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [12:17<00:00, 122.92s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:45<00:00, 105.74s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp2000\exp2300_bbref_nosample"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000_bin20\03_bbref_nosample"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 20, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# Processing Overlap Correction: 100%|████████████| 1/1 [01:46<00:00, 106.18s/it]
# Processing Overlap Correction: 100%|████████████| 7/7 [12:21<00:00, 105.92s/it]
# Processing Overlap Correction: 100%|████████████| 2/2 [03:33<00:00, 106.62s/it]
# Experiments not processed due to low counts (counts threshold) are:  []
