# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\01_Functions')
from overlap_corr_mod_IMAT22 import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3000_LP30_pre_oper_20C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3000_LP30_pre_oper_20C"

# %%
# %load select_directory('info')
info = r"J:\700 Campaigns - internal\2022\PSI22_04NI\exp_times.txt"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To get a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.
#
# #### binning refers to an average of a specific amount of images (x direction -> ToF direction)

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 1/1 [02:04<00:00, 124.96s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3200_LP30_after_oper_20C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3200_LP30_after_oper_20C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 1/1 [01:57<00:00, 117.77s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3300_LP30_10C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3300_LP30_10C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 1/1 [01:58<00:00, 118.14s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3301_LP30_0C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3301_LP30_0C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 1/1 [02:05<00:00, 125.45s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3302_LP30_m10C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3302_LP30_m10C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 1/1 [02:05<00:00, 125.74s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3303_LP30_m20C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3303_LP30_m20C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 1/1 [01:58<00:00, 118.63s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3400_LP30_pre_oper_m25C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3400_LP30_pre_oper_m25C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.93s/it]
# Experiments not processed due to low counts (counts threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp3000\exp3600_LP30_post_oper_m25C"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp3000\exp3600_LP30_post_oper_m25C"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'IMAT auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction', info_dataframe_dir = info)
# Out:
# Experiments that are above 6:40 min or below 4:20 min are:
# IMAT00018716
# IMAT00018717
# IMAT00018718
# IMAT00018738
# IMAT00018739
# IMAT00018744
# IMAT00018789
# IMAT00018801
# IMAT00018811
# IMAT00018812
# IMAT00018814
# IMAT00018815
# IMAT00018816
# IMAT00018817
# IMAT00018839
# IMAT00018866
# IMAT00019125
# IMAT00019197
# IMAT00019204
# IMAT00019205
# IMAT00019206
# IMAT00019207
# IMAT00019208
# IMAT00019250
# IMAT00019256
# IMAT00019352
# IMAT00019412
# ...
# Processing Overlap Correction: 100%|████████████| 2/2 [03:45<00:00, 112.59s/it]
# Experiments not processed due to low counts (counts threshold) are:  []
