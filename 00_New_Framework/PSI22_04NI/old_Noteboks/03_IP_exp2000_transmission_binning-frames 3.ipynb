# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - exp 1XX acquisition 00

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\00_empty_ref02"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000_testing_binnin_2\00_empty_ref02"

# %% [markdown]
# ### Check folders to process

# %%
stack_dict = prep_stack_dict(src_dir)
for key in stack_dict.keys():
    print(key)
# Out:
# 01_ob
# 02_pos00
# 03_ob
# 04_pos01
# 05_ob
# 06_pos02
# 07_ob
# 08_pos03
# 09_ob
# 10_pos04
# 11_ob

# %% [markdown]
# ## Process the reference folder (if not done before)
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
#%store -r exp_param
ref_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000_testing_binnin_2\00_empty_ref02"
ref_dict00 = read_saved_dict (src_dir, proc_folder = ['02_pos00'])
ref_dict01 = read_saved_dict (src_dir, proc_folder = ['04_pos01'])
ref_dict02 = read_saved_dict (src_dir, proc_folder = ['06_pos02'])
ref_dict03 = read_saved_dict (src_dir, proc_folder = ['08_pos03'])
ref_dict04 = read_saved_dict (src_dir, proc_folder = ['10_pos04'])
# Out:
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00,  7.60it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00, 12.80it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00, 14.49it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00, 14.49it/s]
# Reading Images: 100%|████████████████████████████| 1/1 [00:00<00:00, 11.82it/s]

# %%
#dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results"
#saving_step (ref_dict, dst_dir, img_name = 'test')

# %%
# %store ref_dict00
# %store ref_dict01
# %store ref_dict02
# %store ref_dict03
# %store ref_dict04

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]
#HE_LE = (True, [15,30],[30,50])

add_to_dict(exp_param, ['threshold', 'nca', 'use_ref', 'frames_binning_factor'], [0, nca, False, 2])
add_to_dict(exp_param, ['save_energies', 'end_slice'], [False, 38])

# %%
exp_seq =  [binning_frames,
            outlier_removal, # it will remove the 0's in the image, if any
            stack_averaging,
            slice_values_dict,
            scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
            SBKG_correction_dict,
            TFC_correction_dict]

# %% [markdown]
# ## Experiment Empty Ref02 Processing

# %% [markdown]
# ### Full Processing

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.47it/s]
# Experiment 02_pos00 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.15it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.23it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.23it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.15s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:27<00:00,  4.60s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.09s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.02it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.79s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00, 12.29it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.33s/it]
# Total time: 229s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.38s/it]
# Experiment 04_pos01 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.11it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.22it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.15it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.03s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:27<00:00,  4.59s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.10s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.18it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.79s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00, 12.07it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.35s/it]
# Total time: 237s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.56s/it]
# Experiment 06_pos02 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.25it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.26it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.24it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.15s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:28<00:00,  4.67s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.10s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.04it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.83s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00, 12.29it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.36s/it]
# Total time: 257s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.60s/it]
# Experiment 08_pos03 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.19it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.23it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.19it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:01<00:00,  1.99s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:27<00:00,  4.57s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.06s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.02it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.92s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00, 11.18it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.43s/it]
# Total time: 255s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.52s/it]
# Experiment 10_pos04 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.23it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.26it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.24it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.05s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:26<00:00,  4.46s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.01s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.50it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.98s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00, 11.02it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.58s/it]
# Total time: 255s

# %% [markdown]
# ## Experiment LP30 Degraded Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\01_LP30_deg"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000_testing_binnin_2\01_LP30_deg"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict00, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.60s/it]
# Experiment 02_pos00 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.25it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.21it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.20it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.18s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:40<00:00,  6.70s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.02s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.59it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.88s/it]
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  7.72it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.36s/it]
# Total time: 276s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict01, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.44s/it]
# Experiment 04_pos01 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.31it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.23it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.24it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.04s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:37<00:00,  6.26s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.16s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.02it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:03<00:00,  3.08s/it]
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.18it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.43s/it]
# Total time: 282s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict02, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.48s/it]
# Experiment 06_pos02 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  1.95it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.20it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.16it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.14s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:40<00:00,  6.82s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.04s/it]
# Slicing dictionary: 100%|█████████████████████| 1/1 [00:00<00:00, 80659.69it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.61it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:03<00:00,  3.13s/it]
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  7.63it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.36s/it]
# Total time: 284s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict03, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.53s/it]
# Experiment 08_pos03 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.17it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.19it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.23it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.05s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:39<00:00,  6.61s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.03s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.03it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.93s/it]
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.18it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.41s/it]
# Total time: 296s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict04, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.52s/it]
# Experiment 10_pos04 in process...
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.17it/s]
# Processing Binning Frames: 100%|█████████████████| 6/6 [00:02<00:00,  2.16it/s]
# Processing Binning Frames: 100%|█████████████████| 1/1 [00:00<00:00,  2.24it/s]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.03s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [00:39<00:00,  6.65s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.07s/it]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  7.11it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:02<00:00,  2.85s/it]
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.08it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:07<00:00,  7.37s/it]
# Total time: 311s

# %% [markdown]
# ## Experiment LP40 Pristine Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\02_LP40_deg"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000\02_LP40_deg"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)

# %% [markdown]
# ## Experiment BB Ref No Sample Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\03_bbref_nosample"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000\03_bbref_nosample"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'BB_ref_intensity', save = True)
