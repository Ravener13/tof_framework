# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - exp 1XX acquisition 00

# %% [markdown]
# ##  Initial settings

# %% [markdown]
# ### Import libraries
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\01_Functions')
from step_functions import *
from dict_functions import *
from proc_functions import *
from img_functions import *
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000_bin20\00_empty_ref02"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000_bin20\00_empty_ref02"

# %% [markdown]
# ### Check folders to process

# %%
stack_dict = prep_stack_dict(src_dir)
for key in stack_dict.keys():
    print(key)
# Out:
# 01_ob
# 02_pos00
# 03_ob
# 04_pos01
# 05_ob
# 06_pos02
# 07_ob
# 08_pos03
# 09_ob
# 10_pos04
# 11_ob

# %% [markdown]
# ## Process the reference folder (if not done before)
# Or in case it is not previously saved.
#
# In case the parameters and ref_dict are stored in the global variables, you can load them with : `%store -r "name given"`
#
# It is **important** to not process the images fully before having played with them to find the right parameters (there is a notebook called playgound todo this)

# %%
#%store -r exp_param
ref_dir = dst_dir
ref_dict00 = read_saved_dict (src_dir, proc_folder = ['02_pos00'])
ref_dict01 = read_saved_dict (src_dir, proc_folder = ['04_pos01'])
ref_dict02 = read_saved_dict (src_dir, proc_folder = ['06_pos02'])
ref_dict03 = read_saved_dict (src_dir, proc_folder = ['08_pos03'])
ref_dict04 = read_saved_dict (src_dir, proc_folder = ['10_pos04'])

# %%
#dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results"
#saving_step (ref_dict, dst_dir, img_name = 'test')

# %%
# %store ref_dict00
# %store ref_dict01
# %store ref_dict02
# %store ref_dict03
# %store ref_dict04

# %% [markdown]
# ## Base parameters and Sequence

# %%
exp_param = {}
nca = [0,0,0,0]
#HE_LE = (True, [15,30],[30,50])

add_to_dict(exp_param, ['threshold', 'nca', 'use_ref', 'ws_filter_size'], [0, nca, False, 3])
add_to_dict(exp_param, ['end_slice'], [77])

# %%
exp_seq =  [outlier_removal, # it will remove the 0's in the image, if any
            stack_averaging,
            scrubbing_correction_dict, # it will take all the OB frames and not just HE and LE
            SBKG_correction_dict,
            TFC_correction_dict,
            slice_values_dict]

# %% [markdown]
# ## Experiment Empty Ref02 Processing

# %% [markdown]
# ### Full Processing

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:41<00:00, 13.70s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [01:14<00:00, 74.28s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [06:55<00:00, 69.32s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:26<00:00, 26.76s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.06it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.49s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.40it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:12<00:00, 12.24s/it]
# Total time: 580s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:06<00:00,  2.06s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.15s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:52<00:00, 28.77s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.76s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.44it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.29s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.27it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 124.35it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:10<00:00, 10.93s/it]
# Total time: 220s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.38s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.11s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:11<00:00, 21.90s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:24<00:00, 24.98s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.22it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.22s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.42it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 492.46it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.22s/it]
# Total time: 181s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:03<00:00,  1.24s/it]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.06s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:08<00:00, 21.49s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:20<00:00, 20.45s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  4.80it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.96s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.17it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:18<00:00, 18.08s/it]
# Total time: 181s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'empty_ref02_intensity', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.49it/s]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.10s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:09<00:00, 21.63s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.42s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.25it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.01s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  9.01it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 124.31it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.22s/it]
# Total time: 170s

# %% [markdown]
# ## Experiment LP30 Degraded Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000_bin20\01_LP30_deg"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000_bin20\01_LP30_deg"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])
#add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict00, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.50s/it]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:25<00:00, 25.16s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:23<00:00, 23.94s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:18<00:00, 18.72s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.17it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.34s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.77it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:11<00:00, 11.19s/it]
# Total time: 210s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])
#add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict01, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:04<00:00,  1.50s/it]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.11s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:46<00:00, 27.73s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:28<00:00, 28.62s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.29it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.01s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.42it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:12<00:00, 12.10s/it]
# Total time: 220s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])
#add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict02, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:07<00:00,  2.57s/it]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.19s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:44<00:00, 27.40s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:19<00:00, 19.03s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  4.96it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.45s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  9.01it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 124.78it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:14<00:00, 14.63s/it]
# Total time: 216s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])
#add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict03, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:01<00:00,  1.62it/s]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.10s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:31<00:00, 25.32s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:21<00:00, 21.40s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  3.54it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:05<00:00,  5.99s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.42it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:19<00:00, 19.83s/it]
# Total time: 206s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])
#add_to_dict(exp_param,['BB_mask', 'ref_dict', 'use_ref'], [BB_mask, ref_dict04, True])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP30_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.43it/s]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.06s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [02:34<00:00, 25.81s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:24<00:00, 24.47s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.46it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.15s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.18it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:10<00:00, 10.42s/it]
# Total time: 201s

# %% [markdown]
# ## Experiment LP40 Pristine Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000_bin20\02_LP40_deg"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000_bin20\02_LP40_deg"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:01<00:00,  1.54it/s]
# Experiment 02_pos00 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:15<00:00, 15.12s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [01:57<00:00, 19.50s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:14<00:00, 14.91s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.17it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.29s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.19it/s]
# Slicing dictionary: 100%|████████████████████████| 1/1 [00:00<00:00, 23.38it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:10<00:00, 10.56s/it]
# Total time: 167s

# %%
proc_folder = ['04_pos01']
BB_mask = get_img(src_dir + '/pos_01.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:02<00:00,  1.46it/s]
# Experiment 04_pos01 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.13s/it]
# Processing Filetring : 100%|█████████████████████| 7/7 [02:14<00:00, 19.28s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:14<00:00, 14.74s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.19it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.13s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.32it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 490.28it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:10<00:00, 10.40s/it]
# Total time: 171s

# %%
proc_folder = ['06_pos02']
BB_mask = get_img(src_dir + '/pos_02.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:01<00:00,  1.63it/s]
# Experiment 06_pos02 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.11s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [01:59<00:00, 19.91s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:15<00:00, 15.36s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  4.95it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.08s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.19it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:10<00:00, 10.37s/it]
# Total time: 156s

# %%
proc_folder = ['08_pos03']
BB_mask = get_img(src_dir + '/pos_03.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:01<00:00,  1.62it/s]
# Experiment 08_pos03 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.12s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [01:56<00:00, 19.42s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:14<00:00, 14.67s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.17it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.16s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.34it/s]
# Slicing dictionary: 100%|███████████████████████| 1/1 [00:00<00:00, 490.28it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:10<00:00, 10.37s/it]
# Total time: 152s

# %%
proc_folder = ['10_pos04']
BB_mask = get_img(src_dir + '/pos_04.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'LP40_deg_transmission', save = True)
# Out:
# Reading Images: 100%|████████████████████████████| 3/3 [00:01<00:00,  1.69it/s]
# Experiment 10_pos04 in process...
# Processing Filetring : 100%|█████████████████████| 1/1 [00:02<00:00,  2.12s/it]
# Processing Filetring : 100%|█████████████████████| 6/6 [01:55<00:00, 19.28s/it]
# Processing Filetring : 100%|█████████████████████| 1/1 [00:14<00:00, 14.67s/it]
# Processing Scrubbing Correction: 100%|███████████| 1/1 [00:00<00:00,  5.17it/s]
# Processing SBKG Correction: 100%|████████████████| 1/1 [00:04<00:00,  4.06s/it]
# Using proc_dict as both img and ref to calculate TFC
# Processing TFC Correction: 100%|█████████████████| 1/1 [00:00<00:00,  8.93it/s]
# Slicing dictionary: 100%|████████████████████████████████| 1/1 [00:00<?, ?it/s]
# Saving images as a single acquisition
# Writing Images: 100%|████████████████████████████| 1/1 [00:10<00:00, 10.43s/it]
# Total time: 151s

# %% [markdown]
# ## Experiment BB Ref No Sample Processing

# %% [markdown]
# ### Directories

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp2000\03_bbref_nosample"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\01_Transmission_results\exp2000\03_bbref_nosample"

# %% [markdown]
# ### Full Processing (same parameters as the exp before)

# %%
proc_folder = ['02_pos00']
BB_mask = get_img(src_dir + '/pos_00.fits')
add_to_dict(exp_param,['BB_mask'], [BB_mask])

exp_dict = full_processing (src_dir, dst_dir, proc_folder = proc_folder, sequence = exp_seq, 
                 proc_parameters = exp_param, img_name = 'BB_ref_intensity', save = True)
