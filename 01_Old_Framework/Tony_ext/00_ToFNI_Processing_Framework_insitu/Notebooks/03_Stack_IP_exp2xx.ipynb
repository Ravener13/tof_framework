# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - Introduction
# This notebook demonstrates the use of Jupyter for a Time-of-Flight image processing task. The data corresponds to ToF neutron imaging of coin cells filled with different organic compounds and electrolytes.
#
# *Note: This notebook was written and tested on Windows 10. Running on Mac or Linux machines may need adjustments, e.g. in the path specificationsApplied processing*
#
# ### Applied processing
# The following processing parts from the averaged pulses, which were already overlap corrected:
#
# - filtering
# - Pulse averaging and separtion per experiments
# - identification and weighting of OBs for each experiment
# - scrubbing correction
# - intensity correction
# - transmission image generation
#
#
# ### Important Considerations
# This notebook starts from the point **after** the overlap correction presented in the image below. This step before (done in a separate notebook) format its destionation directory to be taken by this notebook to process the images correctly.
#
# Transmission Image:
#
# \begin{equation}
# T_{img} \rightarrow \frac{I}{I_{0}}=\frac{\frac{\bar{Img}}{OB_{weight}} - SBKG_{img}}{\frac{\bar{Ref}}{OB_{weight}} - SBKG_{ref}}
# \end{equation}

# %% [markdown]
# ## 01 Initial settings
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\framework')
sys.path.append(r'..\proc_functions')
from stack_proc_func import *
from img_utils_mod import *
import scipy.signal as sp
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\900 Varia\2021\000_tony_data\03_Processed_step_by_step\00_Overlap_correction\exp2XX"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\900 Varia\2021\000_tony_data\03_Processed_step_by_step\01_transmission_results\exp2XX_new"

# %% [markdown]
# ### Select working folders
# Once the directories are loaded, you can start to do a selection of the folders you want to process. <br>
# The next function loads the folders availableas a visual aid. However, you can avoid this step just by looking at the source folder in the windows explorer.

# %%
all_folders = prep_stack_dict(src_dir)
for key in all_folders.keys():
    print(key)
# Out:
# 00_ob_ini
# 01_so_ref
# 02_exp201_00
# 02_exp201_01
# 02_exp201_02
# 02_exp201_03
# 02_exp201_04
# 02_exp201_05
# 02_exp201_06
# 02_exp201_07
# 02_exp201_08
# 03_ob_end

# %% [markdown]
# For this test we will select some folders that we want to process as '`proc_folder`' and our reference as '`ref_folder`'.
#
# * _note: `proc-folder` can take several strings as value, for that reason is a list of strings. On the other hand, `ref_folder` is always one, for that reason it is just a string._

# %%
proc_folder_01 = ["02_exp201_00","02_exp201_01","02_exp201_02"]
proc_folder_02 = ["02_exp201_03","02_exp201_04","02_exp201_05"]
proc_folder_03 = ["02_exp201_06","02_exp201_07","02_exp201_08"]

ref_folder = '01_so_ref'

# %% [markdown]
# ## 02 Filtering process definition
# Here we define the process that each image will have before the pulse averaging (if any).
#
# * _note: The sequence generated must contain the names of each function and at the end the 'stack_avg' function which performs the pulse averaging. <br> i.e.  test_seq = [`function_1`, `function_2`, `more functions`, `stack_avg`]_

# %% [markdown]
# ### White spots filtering
# The white spots are removed by applying a median filter of size 'ws_filter_size'

# %%
from skimage.filters import gaussian, median, meijering
from skimage.morphology import disk

def ws_filter(src_img, ws_filter_size, **kwargs):
    return sp.medfilt2d(src_img.astype('float32'), ws_filter_size)

def outlier_removal (img, threshold, **kwargs):
    mask_x = np.where(img <= threshold)[0]
    mask_y = np.where(img <= threshold)[1]
    for x, y in zip(mask_x, mask_y) :
        slice = img[max(0, x-1):x+1, max(0,y-1):y+1] # assuming you want 5x5 square
        img[x,y] = np.mean([i for i in slice.flatten() if i > threshold])  # threshold is 0
    return img

# %%
roi_crop = [1, 332, 509, 129]

# %%
test_seq = [crop_img, outlier_removal, stack_avg]

# %% [markdown]
# ## 03 Filter testing
# The `test_filter_stack` function test the filters given in the `test_seq` list and prints the image.<br> A selection of a testing folder named `test_folder` is required to proceed with the image checkout. <br>
# -If no specific image is selected, it automatically selects the image at the median point in the stack.<br>
#
# * _note: if the filtering functions inserted in the `test_seq` require aditional arguments or variables, they can be given as `**kwargs` inside the function parameters. i.e `ws_filter_size = 5` was given in the function for the ws_filter usage._

# %%
test_folder = '02_exp201_08'
img = test_filtering_stack (src_dir,dst_dir, test_folder = test_folder, test_seq = test_seq, give_img=True, threshold = 0,
                            roi_crop = roi_crop, ws_filter_size = 3, img_number = 95)
# Out:
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# ws_filter_size = 3
# Averaging: 100%|███████████████████████████████| 50/50 [00:12<00:00,  3.89it/s]

# %% [markdown]
# ### Confirm the operations sequence
# After you are satisfied with the result, write the real sequence `seq` that will be used for all the images.

# %%
seq = [crop_img, outlier_removal]

# %% [markdown]
# ## 04 Selecting ROIS and other variables
# Each campaign is different, if there are some requirements that the processing require, you can insert them as `**kwargs`. <br>
# In the case of this specific campaing (PSI19_03NI), the MCP detector did not adquire correctly the first 9 images in each process. For that reason, the processing needs to remove those images. Thus, we can slice the folder by givin the values that we want with `start_slice` and `end_slice`.
#
# * _note: If we want to slice the starting but not the end, it is just required to give the beginning (`start_slice`) and leave `end_slice` blank as in the next example._

# %% [markdown]
# ### ROI selection (program still needs the implementation of the CSV option)
# One important parameter are the ROIs, specifically the non-changing-area (nca). Fo that reason, we do a use an interactive command to select them.
#
# If more ROIs were selected (other than the first -nca-), these will be used to create a CSV file at the end with the all the transmission values included. <br>**waiting for implementation in stack_batch_proc**
#
# The window for ROI selection still open in a separate window, I am checking the way to have it printed in the notebook to avoid changing any mistake
#
# * _note: the option 'flip_image = True' is required to agree with imageJ format of showing the image. In stack_batch_proc it is implemented in the intensity correction part (TFC_corr). The modifications done to img_utils _
#
# **to select several ROIs: for each ROI selected, press ENTER, when finish, press ESC**

# %%
# %load select_rois(img, list_rois = ['nca'])
nca = [78, 43, 40, 15]

# %% [markdown]
# To agree with the selected ROIs, the image is shown with its labeling, being label 1 the first ROI selected i.e nca, second label 2 and so forth

# %%
show_img(img, dr = [nca])

# %%
reg_img = get_img(src_dir + '/reg_img_LE.fits')
reg_rois = reg_rois = [([75, 18, 20, 95], 'v'), ([453, 18, 25, 95], 'v')]
show_img_rois(img, dr = [(reg_rois, 'yellow')])

# %%
img_reg_corr, M = img_registration (img, reg_img[0], num_iter =3, method = '3', rois_list = reg_rois, dof=['ty'])

# %%
plt.rcParams['figure.figsize'] = [15, 8]
plt.imshow(img_reg_corr/reg_img[0], cmap = 'flag')
print(M)
# Out:
# [[1.         0.         0.13333333]
#  [0.         1.         0.        ]
#  [0.         0.         1.        ]]

# %% [markdown]
# ## 05 BB mask
# The BB mask is a fits image saved in the source directory. if all the experiments are aligned, one BB mask can be used. However, if there are misalignments, several BB masks must be given.
#
# **a program that creates the BB mask for that specific experiment would be extremly useful in this case so we do not need to care anymore about BBs**
#
# For the moment being and as an example, the program takes a real (for testing) BB mask to include it in the process

# %%
ref_mask_img = get_img(src_dir + '/bb_mask_LE.fits')
img_mask_img = get_img(src_dir + '/bb_mask_LE.fits')

# %% [markdown]
# ## 06 Run first transmission image test
# This will give you one transmission image as an example of the whole process.
#
# Set a starting and ending slice (to speed up the process, do not choose more tan 10 images or do it in different parts of the spectrum)

# %%
stack_test = stack_batch_proc (src_dir, dst_dir, ref_mask_img,img_mask_img, reg_img, proc_folder = [test_folder], 
         ref_folder = ref_folder, avg_seq = seq, save_results = False, start_slice = 30, end_slice = 40, 
         print_TFC = True, nca=nca, threshold = 0, roi_crop =roi_crop, stack_avg=False, scrubbing=True, 
        initial_HE_LE = (False, [3,23],[60,80]),dof=['ty'], rois_list = reg_rois, ws_filter_size = 3, M=M)
# Out:
# start_slice = 30
# end_slice = 40
# print_TFC = True
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# dof = ['ty']
# rois_list = [([75, 18, 20, 95], 'v'), ([453, 18, 25, 95], 'v')]
# ws_filter_size = 3
# M = [[1.         0.         0.33333333]
#  [0.         1.         0.        ]
#  [0.         0.         1.        ]]
# Processing: 100%|████████████████████████████████| 6/6 [01:41<00:00, 16.95s/it]
# Processing: 100%|██████████████████████████████| 24/24 [06:58<00:00, 17.42s/it]
# Processing: 100%|██████████████████████████████| 50/50 [14:21<00:00, 17.23s/it]
# Processing: 100%|████████████████████████████████| 6/6 [01:11<00:00, 11.92s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_08
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\CARREO~1\AppData\Local\Temp/ipykernel_4880/1504124334.py in <module>
# ----> 1 stack_test = stack_batch_proc (src_dir, dst_dir, ref_mask_img,img_mask_img, reg_img, proc_folder = [test_folder],
#       2          ref_folder = ref_folder, avg_seq = seq, save_results = False, start_slice = 30, end_slice = 40,
#       3          print_TFC = True, nca=nca, threshold = 0, roi_crop =roi_crop, stack_avg=False, scrubbing=True,
#       4         initial_HE_LE = (False, [3,23],[60,80]),dof=['ty'], rois_list = reg_rois, ws_filter_size = 3, M=M)
#
# ~\Documents\Python Scripts\tof_framework\Tony_ext\00_ToFNI_Processing_Framework_insitu\Notebooks\..\proc_functions\stack_proc_func.py in stack_batch_proc(src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder, ref_folder, avg_seq, save_results, scrubbing, initial_HE_LE, final_HE_LE, **kwargs)
#    1228     #     save_dict(value, after_img_reg_dir,  overwrite = True, **kwargs)
#    1229
# -> 1230     stack_dict = convert_stack_energies (stack_dict, HE_slice = [1, 21], LE_slice = [74,99])
#    1231
#    1232         # computes the transmission images
#
# ~\Documents\Python Scripts\tof_framework\Tony_ext\00_ToFNI_Processing_Framework_insitu\Notebooks\..\proc_functions\stack_proc_func.py in convert_stack_energies(stack_dict, HE_slice, LE_slice, testing_mode, **kwargs)
#    1463                 LE_avg = np.nanmean(imgs[LE_slice[0]:LE_slice[1]], axis = 0)
#    1464
# -> 1465                 header_HE = values[int((HE_slice[0]+HE_slice[1])/2)][1]
#    1466                 header_LE = values[int((LE_slice[0]+LE_slice[1])/2)][1]
#    1467                     # takes each value in the subfolder (values)
#
# IndexError: list index out of range

# %% [markdown]
# ### Testing the NCA region
#
# This region is characterized for having a value of 1. The process might have an error if this region has values greater that 0.05% of the theoretical one.

# %%
for key, val in stack_test.items():
    print(key)
    for key2, im in val.items():
        print(key2)
        nca_reg =[]
        for arr in im:
            nca_reg.append(np.mean(roi_in_image(arr[0],nca)))
        print('value cropped reg {}'.format(np.mean(nca_reg)))
        print(nca_reg)
print(len(nca_reg))
print('Average value in the NCA is {}'.format(np.mean(nca_reg)))

# %% [markdown]
# ## 07 Full image processing
# After all tests are correct, you can process and do the full image process for all the folders that you want with the captured parameters.
#
# The result of using the next function is that all the transmission images generated with it are saved with a .fits extension in your destination folder and HE and LE sections will be saved in another 2 folders.

# %% [markdown]
# __Note:__ If you are sure fo the process, you can leave `proc_folder` empty `proc_folder = []`,the program will process all folders included in the source directory.

# %%
disp = float(0)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_00"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [77, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# Processing: 100%|████████████████████████████████| 6/6 [03:22<00:00, 33.79s/it]
# Processing: 100%|██████████████████████████████| 24/24 [11:29<00:00, 28.74s/it]
# Processing: 100%|██████████████████████████████| 40/40 [19:59<00:00, 29.99s/it]
# Processing: 100%|████████████████████████████████| 6/6 [03:02<00:00, 30.43s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_00
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 24.83it/s]
# 02_exp201_00
# Processing: 100%|██████████████████████████████| 40/40 [00:03<00:00, 12.95it/s]
# Total execution time: 2325s

# %%
disp = float(0.06667)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_01"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 40,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1.      0.      0.06667]
#  [0.      1.      0.     ]
#  [0.      0.      1.     ]]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.89s/it]
# Processing: 100%|██████████████████████████████| 24/24 [10:30<00:00, 26.25s/it]
# Processing: 100%|██████████████████████████████| 39/39 [21:17<00:00, 32.76s/it]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.87s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_01
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 28.31it/s]
# 02_exp201_01
# Processing: 100%|██████████████████████████████| 39/39 [00:02<00:00, 13.55it/s]
# Total execution time: 2259s

# %%
disp = float(0.06667)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_02"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 79,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1.      0.      0.06667]
#  [0.      1.      0.     ]
#  [0.      0.      1.     ]]
# Processing: 100%|████████████████████████████████| 6/6 [02:40<00:00, 26.77s/it]
# Processing: 100%|██████████████████████████████| 24/24 [10:31<00:00, 26.32s/it]
# Processing: 100%|██████████████████████████████| 40/40 [19:44<00:00, 29.61s/it]
# Processing: 100%|████████████████████████████████| 6/6 [02:40<00:00, 26.83s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_02
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 27.58it/s]
# 02_exp201_02
# Processing: 100%|██████████████████████████████| 40/40 [00:03<00:00, 12.99it/s]
# Total execution time: 2166s

# %%
disp = float(0.1)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_03"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 119,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1.  0.  0.1]
#  [0.  1.  0. ]
#  [0.  0.  1. ]]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.84s/it]
# Processing: 100%|██████████████████████████████| 24/24 [10:31<00:00, 26.30s/it]
# Processing: 100%|██████████████████████████████| 47/47 [23:10<00:00, 29.59s/it]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.93s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_03
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 25.51it/s]
# 02_exp201_03
# Processing: 100%|██████████████████████████████| 47/47 [00:03<00:00, 12.60it/s]
# Total execution time: 2382s

# %%
disp = float(0.1)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_04"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 166,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1.  0.  0.1]
#  [0.  1.  0. ]
#  [0.  0.  1. ]]
# Processing: 100%|████████████████████████████████| 6/6 [02:42<00:00, 27.00s/it]
# Processing: 100%|██████████████████████████████| 24/24 [10:37<00:00, 26.58s/it]
# Processing: 100%|██████████████████████████████| 40/40 [19:39<00:00, 29.49s/it]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.88s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_04
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 28.30it/s]
# 02_exp201_04
# Processing: 100%|██████████████████████████████| 40/40 [00:02<00:00, 13.39it/s]
# Total execution time: 2170s

# %%
disp = float(0.13334)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_05"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 206,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1.      0.      0.13334]
#  [0.      1.      0.     ]
#  [0.      0.      1.     ]]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.96s/it]
# Processing: 100%|██████████████████████████████| 24/24 [10:34<00:00, 26.42s/it]
# Processing: 100%|██████████████████████████████| 40/40 [19:44<00:00, 29.61s/it]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.98s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_05
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 28.39it/s]
# 02_exp201_05
# Processing: 100%|██████████████████████████████| 40/40 [00:03<00:00, 13.17it/s]
# Total execution time: 2171s

# %%
disp = float(0.23334)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_06"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 246,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1.      0.      0.23334]
#  [0.      1.      0.     ]
#  [0.      0.      1.     ]]
# Processing: 100%|████████████████████████████████| 6/6 [02:40<00:00, 26.82s/it]
# Processing: 100%|██████████████████████████████| 24/24 [10:31<00:00, 26.33s/it]
# Processing: 100%|██████████████████████████████| 40/40 [19:29<00:00, 29.24s/it]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.90s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_06
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 28.32it/s]
# 02_exp201_06
# Processing: 100%|██████████████████████████████| 40/40 [00:03<00:00, 13.16it/s]
# Total execution time: 2153s

# %%
disp = float(0.03334)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_07"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 286,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
# print_TFC = False
# nca = [76, 44, 35, 12]
# threshold = 0
# roi_crop = [1, 332, 509, 129]
# stack_avg = False
# M = [[1.      0.      0.03334]
#  [0.      1.      0.     ]
#  [0.      0.      1.     ]]
# Processing: 100%|████████████████████████████████| 6/6 [02:41<00:00, 26.89s/it]
# Processing: 100%|██████████████████████████████| 24/24 [10:33<00:00, 26.41s/it]
# Processing: 100%|██████████████████████████████| 40/40 [19:23<00:00, 29.10s/it]
# Processing: 100%|████████████████████████████████| 6/6 [02:42<00:00, 27.10s/it]
# Performing Scrubbing Correction
# Performing Image Registration for exp 02_exp201_07
# 01_so_ref
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00, 28.25it/s]
# 02_exp201_07
# Processing: 100%|██████████████████████████████| 40/40 [00:02<00:00, 13.86it/s]
# Total execution time: 2151s

# %%
disp = float(0.13334)
M = np.array([[1,0,disp], [0,1,0], [0,0,1]])
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, reg_img, proc_folder = ["02_exp201_08"], print_TFC = False,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, roi_crop =roi_crop,start_numb = 326,
                  stack_avg=False, scrubbing=True,M=M)
# Out:
#   File "C:\Users\CARREO~1\AppData\Local\Temp/ipykernel_4880/3765925871.py", line 1
#     nca = [76 44, 3512]
#               ^
# SyntaxError: invalid syntax
