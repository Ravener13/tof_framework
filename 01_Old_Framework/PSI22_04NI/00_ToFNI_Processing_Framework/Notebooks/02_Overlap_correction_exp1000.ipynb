# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\proc_functions')
from overlap_corr_mod import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp0100\exp0100_lp30_pristine"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\00_LP30_pristine"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To get a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.
#
# #### binning refers to an average of a specific amount of images (x direction -> ToF direction)

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 1/1 [01:38<00:00, 98.19s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [10:27<00:00, 104.64s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:40<00:00, 100.13s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [10:28<00:00, 104.74s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:49<00:00, 109.45s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [10:59<00:00, 109.96s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.46s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:02<00:00, 110.42s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.42s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [10:58<00:00, 109.70s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:49<00:00, 109.56s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp0100\exp0200_lp40_pristine"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\01_LP40_pristine"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|████████████| 1/1 [01:52<00:00, 112.08s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:14<00:00, 112.43s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:52<00:00, 112.18s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:05<00:00, 110.89s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.59s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:02<00:00, 110.35s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:58<00:00, 118.73s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [12:23<00:00, 123.97s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:52<00:00, 112.14s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:07<00:00, 111.28s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:51<00:00, 111.90s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp0100\exp0300_empty_ref"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\02_empty_ref"

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|████████████| 1/1 [01:51<00:00, 111.51s/it]
# Processing Overlap Correction: 100%|████████████| 7/7 [12:58<00:00, 111.21s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.79s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:06<00:00, 111.03s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.77s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:19<00:00, 113.26s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:52<00:00, 112.22s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:05<00:00, 110.88s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.82s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [11:04<00:00, 110.75s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:51<00:00, 111.26s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []
