# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\proc_functions')
from overlap_corr_mod import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2022\PSI22_04NI\Raw_images\exp0100\exp0100_lp30_pristine"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2022\PSI22_04NI\00_Processed\00_Overlap_corrected\exp1000\exp1000_lp30_pristine"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To get a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.
#
# #### binning refers to an average of a specific amount of images (x direction -> ToF direction)

# %%
mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction:   0%|                     | 0/1 [00:00<?, ?it/s]C:\Users\carreon_r\Documents\Python Scripts\tof_framework\PSI22_04NI\00_ToFNI_Processing_Framework\Notebooks\..\proc_functions\overlap_corr_mod.py:422: RuntimeWarning: divide by zero encountered in true_divide
#   dst_img = src_img/(1-p_img)*ref_sh_count/sh_counts[i_sh]
# C:\Users\carreon_r\Documents\Python Scripts\tof_framework\PSI22_04NI\00_ToFNI_Processing_Framework\Notebooks\..\proc_functions\overlap_corr_mod.py:422: RuntimeWarning: invalid value encountered in true_divide
#   dst_img = src_img/(1-p_img)*ref_sh_count/sh_counts[i_sh]
# Processing Overlap Correction: 100%|████████████| 1/1 [01:50<00:00, 110.48s/it]
# Processing Overlap Correction: 100%|████████████| 6/6 [12:27<00:00, 124.55s/it]
# Processing Overlap Correction: 100%|████████████| 1/1 [02:12<00:00, 132.00s/it]
# Processing Overlap Correction:  33%|████        | 2/6 [05:12<10:25, 156.49s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\CARREO~1\AppData\Local\Temp/ipykernel_17348/2997533595.py in <module>
# ----> 1 mcpoc_correct_batch(src, dst, ref_sh_count = 'auto', exp_threshold= 100 , binning = 10, scale=1.0, savetype=float,
#       2                     desc='Processing Overlap Correction')
#
# ~\Documents\Python Scripts\tof_framework\PSI22_04NI\00_ToFNI_Processing_Framework\Notebooks\..\proc_functions\overlap_corr_mod.py in mcpoc_correct_batch(src_dir, dst_basedir, ref_sh_count, exp_threshold, binning, scale, savetype, desc)
#     499
#     500                     # perform the overlap correction on this experiment
# --> 501                 mcpoc_correct_exp(exp_dir, dst_dir, exp_name, ref_sh_count, binning = binning,
#     502                                   scale=scale, savetype=savetype)
#     503             else:
#
# ~\Documents\Python Scripts\tof_framework\PSI22_04NI\00_ToFNI_Processing_Framework\Notebooks\..\proc_functions\overlap_corr_mod.py in mcpoc_correct_exp(src_dir, dst_dir, exp_name, ref_sh_count, binning, scale, savetype)
#     405
#     406                 # get the source image
# --> 407             src_img, timestamp = mcpoc_read_img(src_dir, exp_name, i_bin)
#     408
#     409                 # get the image dimensions
#
# ~\Documents\Python Scripts\tof_framework\PSI22_04NI\00_ToFNI_Processing_Framework\Notebooks\..\proc_functions\overlap_corr_mod.py in mcpoc_read_img(src_dir, exp_name, index)
#     317         # read the file
#     318     with fits.open(fname) as f:
# --> 319         time_data = os.path.getmtime(fname)
#     320         time_mod = time.ctime(os.path.getmtime(fname))
#     321         img = (f[0].data)
#
# ~\Anaconda3\lib\genericpath.py in getmtime(filename)
#      53 def getmtime(filename):
#      54     """Return the last modification time of a file, reported by os.stat()."""
# ---> 55     return os.stat(filename).st_mtime
#      56
#      57
#
# KeyboardInterrupt:
