# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\proc_functions')
from overlap_corr_mod import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2021\PSI21_22NI\110_raw_sorted\exp410"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp410"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To have a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.

# %%
mcpoc_correct_batch(src, dst, 9000 , exp_threshold= 500, scale=1.0, savetype=float, desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 6/6 [04:39<00:00, 46.57s/it]
# Processing Overlap Correction: 100%|███████| 375/375 [6:53:18<00:00, 66.13s/it]
# Experiments not processed due to low counts (exp_threshold) are:  ['exp410_long_prot_034', 'exp410_long_prot_067', 'exp410_long_prot_112', 'exp410_long_prot_113', 'exp410_long_prot_114', 'exp410_long_prot_280', 'exp410_long_prot_281']

# %%
# %load select_directory('src_ref')
src_ref = r"J:\700 Campaigns - internal\2021\PSI21_22NI\110_raw_sorted\ref_bb"

# %%
# %load select_directory('dst_ref')
dst_ref =  r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp410"

# %%
mcpoc_correct_batch(src_ref, dst_ref, 9000 , exp_threshold= 4500, scale=1.0, savetype=float, 
                    desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|███████████| 14/14 [10:35<00:00, 45.40s/it]
# Processing Overlap Correction: 100%|█████████████| 8/8 [03:44<00:00, 28.01s/it]
# Processing Overlap Correction: 100%|█████████████| 7/7 [03:15<00:00, 27.92s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []
