# %% [markdown]
# # Image processing notebook: Sorting script or MCP with metadata.txt
#
# ### 00 - Introduction
#
#
# ### Applied processing
#
#
#
# ### Important Considerations
# it is better to do it exp by exp
#
# The dst folder will have two numbers as identifiers at the beginning, they are in order according to the processing

# %%
import sys
sys.path.append(r'..\proc_functions')
from sort_w_metadata import *

# %%
# %load select_directory('src_dir')
src_dir = r"H:\700 Campaigns - internal\2021\PSI21_22NI\arch\100_images\exp500_ref"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\110_raw_sorted\exp500_ref"

# %%
metadata_list = filter_files_dir (src_dir, file_name= 'Metadata.txt')

# %%
Sorted_data = read_n_sort_metadata (metadata_list, max_number_exps = 1000)

# %%
copy_sorted_files(src_dir, dst_dir, Sorted_data, start_numbering = 0, action = 'copy')
# Out:
# Copying...:   0%|                                        | 0/3 [00:00<?, ?it/s]
# ['exp500_ref000', 'exp500_ref000', 'exp500_ref001', 'exp500_ref002', 'exp500_ref003', 'exp500_ref004', 'exp500_ref005']
# 805
# Copying...:  33%|██████████▎                    | 1/3 [02:12<04:24, 132.05s/it]
# ['exp500_ref006', 'exp500_ref007', 'exp500_ref008', 'exp500_ref009', 'exp500_ref010', 'exp500_ref011', 'exp500_ref012', 'exp500_ref013', 'exp500_ref014', 'exp500_ref015', 'exp500_ref016', 'exp500_ref017', 'exp500_ref018', 'exp500_ref019', 'exp500_ref020', 'exp500_ref021', 'exp500_ref022', 'exp500_ref023', 'exp500_ref024', 'exp500_ref025', 'exp500_ref026', 'exp500_ref027', 'exp500_ref028', 'exp500_ref029', 'exp500_ref030', 'exp500_ref031', 'exp500_ref032', 'exp500_ref033', 'exp500_ref034', 'exp500_ref035']
# 3450
# Copying...:  67%|████████████████████▋          | 2/3 [12:30<06:58, 418.30s/it]
# ['exp500_ref036', 'exp500_ref037', 'exp500_ref038', 'exp500_ref039', 'exp500_ref040', 'exp500_ref041']
# 690
# Copying...: 100%|███████████████████████████████| 3/3 [14:36<00:00, 292.02s/it]
