# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\proc_functions')
from overlap_corr_mod import *

# %%
# %load select_directory('src')
src = r"J:\700 Campaigns - internal\2021\PSI21_22NI\110_raw_sorted\exp400"

# %%
# %load select_directory('dst')
dst = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp400"

# %%
mcpoc_correct_batch(src, dst, 9000 , scale=1.0, savetype=float, desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 5/5 [02:20<00:00, 28.07s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:38<00:00, 27.95s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:37<00:00, 27.93s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:36<00:00, 27.92s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:36<00:00, 27.91s/it]
# Processing Overlap Correction: 100%|███████████| 54/54 [25:06<00:00, 27.90s/it]
# Processing Overlap Correction: 100%|███████████| 41/41 [19:01<00:00, 27.85s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:32<00:00, 27.81s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:32<00:00, 27.82s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:35<00:00, 27.89s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:36<00:00, 27.91s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [25:52<00:00, 38.81s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [32:24<00:00, 48.61s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [24:40<00:00, 37.02s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [19:33<00:00, 29.33s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [19:17<00:00, 28.95s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [19:54<00:00, 29.87s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:54<00:00, 28.36s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:50<00:00, 28.27s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:47<00:00, 28.19s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:44<00:00, 28.12s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:46<00:00, 28.15s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:45<00:00, 28.14s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [18:43<00:00, 28.08s/it]
# Processing Overlap Correction: 100%|███████████| 47/47 [22:01<00:00, 28.13s/it]
# Processing Overlap Correction:  83%|██████████▊  | 5/6 [02:21<00:28, 28.24s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\CARREO~1\AppData\Local\Temp/ipykernel_5452/3058498107.py in <module>
# ----> 1 mcpoc_correct_batch(src, dst, 9000 , scale=1.0, savetype=float, desc='Processing Overlap Correction')
#
# ~\Documents\Python Scripts\tof_framework\PSI21_22NI\01_ToFNI_Processing_Framework_temps\Notebooks\..\proc_functions\overlap_corr_mod.py in mcpoc_correct_batch(src_dir, dst_basedir, ref_sh_count, scale, savetype, desc)
#     451
#     452                 # perform the overlap correction on this experiment
# --> 453             mcpoc_correct_exp(exp_dir, dst_dir, exp_name, ref_sh_count,
#     454                               scale=scale, savetype=savetype)
#     455
#
# ~\Documents\Python Scripts\tof_framework\PSI21_22NI\01_ToFNI_Processing_Framework_temps\Notebooks\..\proc_functions\overlap_corr_mod.py in mcpoc_correct_exp(src_dir, dst_dir, exp_name, ref_sh_count, scale, savetype)
#     357
#     358         # get the measured shutters counts
# --> 359     sh_counts = mcpoc_get_shutter_counts(src_dir, exp_name)
#     360
#     361         # get the number of shutters
#
# ~\Documents\Python Scripts\tof_framework\PSI21_22NI\01_ToFNI_Processing_Framework_temps\Notebooks\..\proc_functions\overlap_corr_mod.py in mcpoc_get_shutter_counts(src_dir, exp_name)
#     177 def mcpoc_get_shutter_counts(src_dir, exp_name):
#     178
# --> 179     return mcpoc_read_txt(src_dir, exp_name, SCOUNT_NAME, 1)
#     180
#     181 """
#
# ~\Documents\Python Scripts\tof_framework\PSI21_22NI\01_ToFNI_Processing_Framework_temps\Notebooks\..\proc_functions\overlap_corr_mod.py in mcpoc_read_txt(src_dir, exp_name, ftype, usecols)
#     147         # (checks if the array is 1D or 2D)
#     148     if len(vals.shape) == 1:
# --> 149         vals = vals[0:max(np.nonzero(vals)[0])+1]
#     150     else:
#     151         vals = vals[0:max(np.nonzero(vals[:,0])[0])+1,:]
#
# ValueError: max() arg is an empty sequence

# %%
# %load select_directory('src_ref')
src_ref = r"J:\700 Campaigns - internal\2021\PSI21_22NI\110_raw_sorted\ref_bb"

# %%
# %load select_directory('dst_ref')
dst_ref =  r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp400"

# %%
mcpoc_correct_batch(src_ref, dst_ref, 9000 , scale=1.0, savetype=float, desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|███████████| 14/14 [07:16<00:00, 31.20s/it]
# Processing Overlap Correction: 100%|█████████████| 8/8 [04:08<00:00, 31.07s/it]
# Processing Overlap Correction: 100%|█████████████| 7/7 [03:38<00:00, 31.22s/it]
