# %% [markdown]
# # Image processing notebook: from Transmission images to ROI-specific relative attenuation
#
# ### 00 - Introduction
#
#
# ### Applied processing

# %%
import sys
sys.path.append(r'..\framework')
sys.path.append(r'..\proc_functions')
sys.path.append(r'..\utilities')
from stack_proc_func import *
from relative_attenuation import *
# %matplotlib inline

# %% [markdown]
# Where the transmission images are

# %%
# %load select_directory('HE_dir')
HE_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\01_Transmission_results\exp410\HE_stack_full_trans_p0"

# %%
# %load select_directory('LE_dir')
LE_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\01_Transmission_results\exp410\LE_stack_full_trans_p0"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\02_Relative_att_res\exp410"

# %% [markdown]
# This will save the relative attenuation images in the given folder

# %%
get_relative_att_HE_LE (dst_dir, HE_dir, LE_dir, start_numb = 0)
