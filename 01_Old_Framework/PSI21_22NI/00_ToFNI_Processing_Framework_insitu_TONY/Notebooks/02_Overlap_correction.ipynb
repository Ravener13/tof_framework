# %% [markdown]
# # Image processing notebook: Overlap Correction and Pulse Averaging
#
# ## 00 - Introduction
# This notebook gives the overlap corrected images and the images with averaged pulses. After this process, the image post processing should be applied to get the transmission image.
#
# ## IMPORTANT
# This is valid for the experiments ordered for the `scrubbing` correction.
#
# **check any of the ShutterCount.txt files in the experiment to know the neutron count. Do not forget to modify it**
#
# ### Applied processing
# The following processing is performed:
#
# - Overlap Correction
#
#
# ### General notebook concept
# The general concept of this notebook is to perform the overlap correction and the averaging of the experiments as shown in the figure.

# %%
import sys
sys.path.append(r'..\proc_functions')
from overlap_corr_mod import *

# %%
# %load select_directory('src')
src = r"J:\900 Varia\2021\000_tony_data\02_rawdata\exp1XX_proc"

# %%
# %load select_directory('dst')
dst = r"J:\900 Varia\2021\000_tony_data\03_Processed_step_by_step\00_Overlap_correction\exp1XX"

# %% [markdown]
# #### exp_threshold is the minimum average z-values in the image. To get a bigger picture and correct value, load all the SummedImg from the experiment in imageJ and make a Z-projection.

# %%
mcpoc_correct_batch(src, dst, 9000, exp_threshold= 100 , scale=1.0, savetype=float, desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|█████████████| 5/5 [03:54<00:00, 46.87s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [49:54<00:00, 74.86s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [50:28<00:00, 75.71s/it]
# Processing Overlap Correction: 100%|███████████| 39/39 [39:40<00:00, 61.03s/it]
# Processing Overlap Correction: 100%|███████████| 40/40 [40:32<00:00, 60.81s/it]
# Processing Overlap Correction: 100%|███████████| 42/42 [37:29<00:00, 53.56s/it]
# Processing Overlap Correction: 100%|█████████████| 6/6 [05:10<00:00, 51.72s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []

# %%
# %load select_directory('src_ref')
src_ref = r"J:\900 Varia\2021\000_tony_data\02_rawdata\refs_expXX\ref_1XX"

# %%
# %load select_directory('dst_ref')
dst_ref = r"J:\900 Varia\2021\000_tony_data\03_Processed_step_by_step\00_Overlap_correction\exp1XX"

# %%
mcpoc_correct_batch(src_ref, dst_ref, 9000 , exp_threshold= 100, scale=1.0, savetype=float, desc='Processing Overlap Correction')
# Out:
# Processing Overlap Correction: 100%|███████████| 25/25 [22:08<00:00, 53.13s/it]
# Experiments not processed due to low counts (exp_threshold) are:  []
