# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - Introduction
# This notebook demonstrates the use of Jupyter for a Time-of-Flight image processing task. The data corresponds to ToF neutron imaging of coin cells filled with different organic compounds and electrolytes.
#
# *Note: This notebook was written and tested on Windows 10. Running on Mac or Linux machines may need adjustments, e.g. in the path specificationsApplied processing*
#
# ### Applied processing
# The following processing parts from the averaged pulses, which were already overlap corrected:
#
# - filtering
# - Pulse averaging and separtion per experiments
# - identification and weighting of OBs for each experiment
# - scrubbing correction
# - intensity correction
# - transmission image generation
#
#
# ### Important Considerations
# This notebook starts from the point **after** the overlap correction presented in the image below. This step before (done in a separate notebook) format its destionation directory to be taken by this notebook to process the images correctly.
#
# Transmission Image:
#
# \begin{equation}
# T_{img} \rightarrow \frac{I}{I_{0}}=\frac{\frac{\bar{Img}}{OB_{weight}} - SBKG_{img}}{\frac{\bar{Ref}}{OB_{weight}} - SBKG_{ref}}
# \end{equation}

# %% [markdown]
# ## 01 Initial settings
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\framework')
sys.path.append(r'..\proc_functions')
from stack_proc_func import *
from img_utils_mod import *
import scipy.signal as sp
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp420"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\01_Transmission_results\exp420"

# %% [markdown]
# ### Select working folders
# Once the directories are loaded, you can start to do a selection of the folders you want to process. <br>
# The next function loads the folders availableas a visual aid. However, you can avoid this step just by looking at the source folder in the windows explorer.

# %%
all_folders = prep_stack_dict(src_dir)
for key in all_folders.keys():
    print(key)
# Out:
# 000_ 00_ob_ini
# 001_exp420_temp_00_p50_prot_01
# 001_exp420_temp_00_p50_prot_02
# 001_exp420_temp_00_p50_prot_03
# 001_exp420_temp_00_p50_prot_04
# 001_exp420_temp_00_p50_prot_05
# 097_ob
# 098_ref_bb
# 099_ob

# %% [markdown]
# For this test we will select some folders that we want to process as '`proc_folder`' and our reference as '`ref_folder`'.
#
# * _note: `proc-folder` can take several strings as value, for that reason is a list of strings. On the other hand, `ref_folder` is always one, for that reason it is just a string._

# %%
proc_folder0 = ['001_exp420_temp_00_p50_prot_01']
proc_folder1 = ['001_exp420_temp_00_p50_prot_02']
proc_folder2 = ['001_exp420_temp_00_p50_prot_03']
proc_folder3 = ['001_exp420_temp_00_p50_prot_04']
proc_folder4 = ['001_exp420_temp_00_p50_prot_05']

ref_folder = '098_ref_bb'

# %% [markdown]
# ## 02 Filtering process definition
# Here we define the process that each image will have before the pulse averaging (if any).
#
# * _note: The sequence generated must contain the names of each function and at the end the 'stack_avg' function which performs the pulse averaging. <br> i.e.  test_seq = [`function_1`, `function_2`, `more functions`, `stack_avg`]_

# %% [markdown]
# ### White spots filtering
# The white spots are removed by applying a median filter of size 'ws_filter_size'

# %%
from skimage.filters import gaussian, median, meijering
from skimage.morphology import disk

def ws_filter(src_img, ws_filter_size, **kwargs):
    return sp.medfilt2d(src_img.astype('float32'), ws_filter_size)

def outlier_removal (img, threshold, **kwargs):
    mask_x = np.where(img <= threshold)[0]
    mask_y = np.where(img <= threshold)[1]
    for x, y in zip(mask_x, mask_y) :
        slice = img[max(0, x-1):x+1, max(0,y-1):y+1] # assuming you want 5x5 square
        img[x,y] = np.mean([i for i in slice.flatten() if i > threshold])  # threshold is 0
    return img

# %%
#roi_crop = [1, 356, 509, 129]

# %%
test_seq = [outlier_removal, stack_avg]

# %% [markdown]
# ## 03 Filter testing
# The `test_filter_stack` function test the filters given in the `test_seq` list and prints the image.<br> A selection of a testing folder named `test_folder` is required to proceed with the image checkout. <br>
# -If no specific image is selected, it automatically selects the image at the median point in the stack.<br>
#
# * _note: if the filtering functions inserted in the `test_seq` require aditional arguments or variables, they can be given as `**kwargs` inside the function parameters. i.e `ws_filter_size = 5` was given in the function for the ws_filter usage._

# %%
test_folder = '001_exp420_temp_00_p50_prot_01'
img = test_filtering_stack (src_dir,dst_dir, test_folder = test_folder, test_seq = test_seq, give_img=True, threshold = 0,
                            ws_filter_size = 3)
# Out:
# threshold = 0
# ws_filter_size = 3
# Averaging: 100%|███████████████████████████████| 80/80 [00:31<00:00,  2.52it/s]

# %% [markdown]
# ### Confirm the operations sequence
# After you are satisfied with the result, write the real sequence `seq` that will be used for all the images.

# %%
seq = [outlier_removal]

# %% [markdown]
# ## 04 Selecting ROIS and other variables
# Each campaign is different, if there are some requirements that the processing require, you can insert them as `**kwargs`. <br>
# In the case of this specific campaing (PSI19_03NI), the MCP detector did not adquire correctly the first 9 images in each process. For that reason, the processing needs to remove those images. Thus, we can slice the folder by givin the values that we want with `start_slice` and `end_slice`.
#
# * _note: If we want to slice the starting but not the end, it is just required to give the beginning (`start_slice`) and leave `end_slice` blank as in the next example._

# %% [markdown]
# ### ROI selection (program still needs the implementation of the CSV option)
# One important parameter are the ROIs, specifically the non-changing-area (nca). Fo that reason, we do a use an interactive command to select them.
#
# If more ROIs were selected (other than the first -nca-), these will be used to create a CSV file at the end with the all the transmission values included. <br>**waiting for implementation in stack_batch_proc**
#
# The window for ROI selection still open in a separate window, I am checking the way to have it printed in the notebook to avoid changing any mistake
#
# * _note: the option 'flip_image = True' is required to agree with imageJ format of showing the image. In stack_batch_proc it is implemented in the intensity correction part (TFC_corr). The modifications done to img_utils _
#
# **to select several ROIs: for each ROI selected, press ENTER, when finish, press ESC**

# %%
# %load select_rois(img, list_rois = ['nca'])
nca = [119, 400, 304, 80]

# %% [markdown]
# To agree with the selected ROIs, the image is shown with its labeling, being label 1 the first ROI selected i.e nca, second label 2 and so forth

# %%
show_img(img, dr = [nca])

# %% [markdown]
# ## 05 BB mask
# The BB mask is a fits image saved in the source directory. if all the experiments are aligned, one BB mask can be used. However, if there are misalignments, several BB masks must be given.
#
# **a program that creates the BB mask for that specific experiment would be extremly useful in this case so we do not need to care anymore about BBs**
#
# For the moment being and as an example, the program takes a real (for testing) BB mask to include it in the process

# %%
ref_mask_img = get_img(src_dir + '/bb_mask_ref.fits')
img_mask_img = get_img(src_dir + '/bb_mask_prot.fits')

# %% [markdown]
# ## 06 Run first transmission image test
# This will give you one transmission image as an example of the whole process.
#
# Set a starting and ending slice (to speed up the process, do not choose more tan 10 images or do it in different parts of the spectrum)

# %%
stack_test = stack_batch_proc (src_dir, dst_dir, ref_mask_img,img_mask_img, proc_folder = [test_folder], 
         ref_folder = ref_folder, avg_seq = seq, save_results = False, start_slice = 30, end_slice = 40, 
         print_TFC = True, nca=nca, threshold = 0, stack_avg=False, scrubbing=True, initial_HE_LE = (False, [3,23],[60,80]))

# %% [markdown]
# ### Testing the NCA region
#
# This region is characterized for having a value of 1. The process might have an error if this region has values greater that 0.05% of the theoretical one.

# %%
for key, val in stack_test.items():
    print(key)
    for key2, im in val.items():
        print(key2)
        nca_reg =[]
        for arr in im:
            nca_reg.append(np.mean(roi_in_image(arr[0],nca)))
        print('value cropped reg {}'.format(np.mean(nca_reg)))
        print(nca_reg)
print(len(nca_reg))
print('Average value in the NCA is {}'.format(np.mean(nca_reg)))

# %% [markdown]
# ## 07 Full image processing
# After all tests are correct, you can process and do the full image process for all the folders that you want with the captured parameters.
#
# The result of using the next function is that all the transmission images generated with it are saved with a .fits extension in your destination folder and HE and LE sections will be saved in another 2 folders.

# %% [markdown]
# __Note:__ If you are sure fo the process, you can leave `proc_folder` empty `proc_folder = []`,the program will process all folders included in the source directory.

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder0, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 6)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 6
# Processing: 100%|████████████████████████████████| 5/5 [03:53<00:00, 46.75s/it]
# Processing: 100%|████████████████████████████| 80/80 [1:01:56<00:00, 46.46s/it]
# Processing: 100%|██████████████████████████████| 14/14 [10:48<00:00, 46.33s/it]
# Processing: 100%|████████████████████████████████| 8/8 [06:26<00:00, 48.32s/it]
# Processing: 100%|████████████████████████████████| 7/7 [05:03<00:00, 43.30s/it]
# Performing Scrubbing Correction
# 001_exp420_temp_00_p50_prot_01
# Processing: 100%|██████████████████████████████| 80/80 [00:35<00:00,  2.26it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.84it/s]
# 1.0378431982948084
# 0.9622354849355964
# 1.0298239896198362
# 0.9521881494690435
# 1.0281600663287271
# 0.9512260432951946
# 1.0304622197807007
# 0.9504362474942144
# 1.0317543828989433
# 0.9502186411160671
# 1.0323378853981766
# 0.9533106713199696
# 1.0300755529185701
# 0.9536834437501894
# 1.0307494868450024
# 0.9527372754877649
# 1.0321276853432841
# 0.9541787245772485
# 1.0336968684951124
# 0.9564291409838617
# 1.029201311926647
# 0.9551358582465714
# 1.0313127741272188
# 0.9550482870827931
# 1.0312535416791253
# 0.9533260301952611
# 1.0302577462351385
# 0.9532221957984851
# 1.0291238842414931
# 0.9527046496480622
# 1.0302561538962656
# 0.9536733326389996
# 1.0310359195365975
# 0.952914543956127
# 1.0307367854887008
# 0.9552123427456372
# 1.033153805705456
# 0.9555523329715518
# 1.0343722225463594
# 0.9603610915959014
# 1.0338450011161304
# 0.9570346947000684
# 1.0342795330439534
# 0.956730323133735
# 1.0340090381540212
# 0.9550307839890542
# 1.036840018051174
# 0.9621053314702112
# 1.037113294025225
# 0.9639545390578353
# 1.0389577740827936
# 0.9609426738730178
# 1.0397461885362091
# 0.9619811893788397
# 1.0379893810210314
# 0.9595278892385485
# 1.0402860802924703
# 0.9650469889496508
# 1.0393097292370006
# 0.9595911475419944
# 1.0393381103813497
# 0.9613880706812963
# 1.0407950467574774
# 0.9629308735453029
# 1.0412990287480561
# 0.9608254897400875
# 1.0421257970279336
# 0.9645568479878137
# 1.0419238035725529
# 0.9608491992861411
# 1.0422176537938885
# 0.9680435479112219
# 1.0421708743884206
# 0.960147696884766
# 1.0405750905532618
# 0.9636035348973607
# 1.0431305655666974
# 0.9638779163211908
# 1.0410069206998398
# 0.9632657697588132
# 1.0382604859998668
# 0.9652974389608326
# 1.0405380186991784
# 0.9631598852647837
# 1.0429787371161525
# 0.9644590527626189
# 1.0426176115870267
# 0.9636943000369286
# 1.0406597804613964
# 0.9644639110087744
# 1.038844138378052
# 0.9616450329937676
# 1.036973021091124
# 0.9629888406628818
# 1.0364009911839125
# 0.9598759314667041
# 1.038816681613165
# 0.9610206017166496
# 1.0354562874879083
# 0.9591421080187478
# 1.0408796682388226
# 0.9659918834366097
# 1.0412551832129393
# 0.9666887481359715
# 1.0423093262707885
# 0.9645419923921532
# 1.0381250343378103
# 0.9622870153826403
# 1.0422980105263135
# 0.9602531402814953
# 1.0401198059147612
# 0.9621102380470631
# 1.0401261067473586
# 0.9609064372537325
# 1.0386654618467892
# 0.9626638627605127
# 1.038001645430976
# 0.9609444681708726
# 1.0390434102285593
# 0.9614228475298846
# 1.0392535584341576
# 0.9622983664356658
# 1.039345606815164
# 0.9605854510255964
# 1.0400262113049212
# 0.9588626822651863
# 1.0415237936663422
# 0.9631109274054649
# 1.039037855237431
# 0.9640300425993257
# 1.0415325379963225
# 0.9666377800635588
# 1.0406574592800206
# 0.9653534884685163
# 1.0384900086123623
# 0.9620960463365124
# 1.0407025422346694
# 0.9646479935471053
# 1.0395772247760386
# 0.9635503963413539
# 1.038553833223838
# 0.9613236287994468
# 1.0377029622249776
# 0.9625865451738543
# 1.039395032672686
# 0.9641926262163159
# 1.0362730922228875
# 0.9638811872552412
# 1.0345557330264725
# 0.9587142404365753
# 1.0354195796248773
# 0.9608894184462033
# 1.034334761402107
# 0.9580302156752427
# 2.353662787850877
# 2.215169998467633
# 1.033617007202333
# 0.9564134211487185
# 1.0333795966726234
# 0.9560355154729746
# Total execution time: 5538s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder1, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 86)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 86
# Processing: 100%|████████████████████████████████| 5/5 [03:28<00:00, 41.72s/it]
# Processing: 100%|████████████████████████████| 79/79 [1:01:57<00:00, 47.06s/it]
# Processing: 100%|██████████████████████████████| 14/14 [10:09<00:00, 43.57s/it]
# Processing: 100%|████████████████████████████████| 8/8 [05:17<00:00, 39.70s/it]
# Processing: 100%|████████████████████████████████| 7/7 [04:57<00:00, 42.51s/it]
# Performing Scrubbing Correction
# 001_exp420_temp_00_p50_prot_02
# Processing: 100%|██████████████████████████████| 79/79 [00:34<00:00,  2.27it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.83it/s]
# 1.0347480850197488
# 0.9571169578103237
# 1.0356967412984954
# 0.9587157857027778
# 1.0346229144564996
# 0.9573833545956665
# 1.035955161391793
# 0.9562437862659108
# 1.035186495479057
# 0.9588100745194906
# 1.033873341984622
# 0.9576511437742194
# 1.0372838044637758
# 0.9606714195765014
# 1.0386050262372903
# 0.961497621471979
# 1.0399716896285962
# 0.9656660517372505
# 1.0401070466905922
# 0.964312934091205
# 1.0391595371345217
# 0.9629006279534111
# 1.0401278153790534
# 0.9627690767145124
# 1.042723231051011
# 0.9633745936355997
# 1.0418295610529522
# 0.9652664545275241
# 1.0399454867423132
# 0.9653135262456245
# 1.041124037855439
# 0.9659915526663556
# 1.0404279354454
# 0.9627214928572121
# 1.0424434343557287
# 0.966535052178191
# 1.041493719658592
# 0.9651245633409763
# 1.0419865805577697
# 0.9641947924034093
# 1.041100047693801
# 0.9666634404752286
# 1.0437255172676907
# 0.9657023255770587
# 1.0449863357957134
# 0.9640714918885832
# 1.0427958753950197
# 0.9659671398854547
# 1.0410833635928909
# 0.9637406675109563
# 1.0427449298139153
# 0.9677061817666258
# 1.044356864196969
# 0.9666212919519581
# 1.043298707976031
# 0.9654509120970411
# 1.044880719835179
# 0.9677794129857711
# 1.0458673624981758
# 0.9682120200269592
# 1.0487213648053677
# 0.9711183392562069
# 1.0456908357851455
# 0.9732207851362298
# 1.0464186370136523
# 0.9670338580547886
# 1.0477797328965652
# 0.9712348410561014
# 1.0475877556542084
# 0.9716032055966073
# 1.0495169198411913
# 0.9699484284005676
# 1.049024035366968
# 0.9695767350220581
# 1.047749015318232
# 0.9704528571377953
# 1.0494242096993496
# 0.9704816932106255
# 1.0472654367703391
# 0.9716647790280986
# 1.0504148928785877
# 0.9752764697381462
# 1.0485410082665387
# 0.9710864030031378
# 1.047304057632584
# 0.9715203123655701
# 1.0462626262620593
# 0.9716599767254099
# 1.0478015928208626
# 0.9686536110191571
# 1.0469384394820882
# 0.9696149220281016
# 1.0491746690612789
# 0.9696694391974546
# 1.0483380404564453
# 0.9744891829733529
# 1.050073530958975
# 0.9735516580609174
# 1.0493259489889344
# 0.968681694322842
# 1.0478984451310158
# 0.9703255632243267
# 1.0465310000154635
# 0.9705257515001756
# 1.0483248947867687
# 0.9691603304543505
# 1.0489666825697963
# 0.9750019717442411
# 3.474763845564728
# 3.3841364020133553
# 3.902856488816843
# 3.758970687756898
# 1.0631628089517646
# 0.9780846995706827
# 1.0603313388443174
# 0.9785392715446501
# 1.059024539280373
# 0.9786529381226043
# 1.0573302911613798
# 0.9757564328649582
# 1.440990815871453
# 1.3449937701295096
# 1.0650996015069187
# 0.9827337006224951
# 1.054769228004913
# 0.9736926219819545
# 1.0534985590762245
# 0.9730564442269842
# 1.0536564292916097
# 0.9711851048151152
# 1.053325983153045
# 0.9731313315885523
# 1.0551613963918451
# 0.9705659504830768
# 1.0533060428768481
# 0.9745444201183039
# 1.0540196182778445
# 0.9719007355079644
# 1.0529987157676386
# 0.973519182998922
# 1.0517467198402102
# 0.9693080385961174
# 1.0529956058825578
# 0.9730455251971908
# 1.0533843614613712
# 0.9716752394411747
# 1.053493138680586
# 0.9734014309827544
# 1.0558392353283126
# 0.9756340979708213
# 1.0532367230612771
# 0.9717147667567768
# 1.055214315700183
# 0.9753796811292905
# 1.05446620293505
# 0.9738724421692782
# 1.0528544185178812
# 0.9722844269598546
# Total execution time: 5397s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder2, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 166)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 166
# Processing: 100%|████████████████████████████████| 5/5 [03:28<00:00, 41.78s/it]
# Processing: 100%|████████████████████████████| 80/80 [1:02:34<00:00, 46.93s/it]
# Processing: 100%|██████████████████████████████| 14/14 [07:41<00:00, 32.94s/it]
# Processing: 100%|████████████████████████████████| 8/8 [04:30<00:00, 33.79s/it]
# Processing: 100%|████████████████████████████████| 7/7 [03:54<00:00, 33.50s/it]
# Performing Scrubbing Correction
# 001_exp420_temp_00_p50_prot_03
# Processing: 100%|██████████████████████████████| 80/80 [00:34<00:00,  2.29it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.95it/s]
# 1.0520773461449255
# 0.9748577588850917
# 1.0553959002682605
# 0.9736965873386022
# 1.0542130550220825
# 0.9728235379154186
# 1.0552642090018465
# 0.9793683823197891
# 1.0544182145693766
# 0.9744662611956242
# 1.0562662285953794
# 0.9746906979438403
# 1.0547523385443687
# 0.9759469702611229
# 1.0556315867770567
# 0.9788571178491117
# 1.0535713059947052
# 0.9737412508948486
# 1.0530935468700708
# 0.9792169037560576
# 1.056091351820487
# 0.9773686448343393
# 1.0547261891785482
# 0.9744657850753486
# 1.0553413244430796
# 0.9759167519078474
# 1.0568242959790277
# 0.9753450872937787
# 1.055469508977979
# 0.9748971133162153
# 1.0549259183790405
# 0.9801199840087417
# 1.0544350677973349
# 0.9774208392118634
# 1.0580033860765083
# 0.9775977965156772
# 1.0560075870113594
# 0.9784568027491204
# 1.054602228790945
# 0.9755163090578199
# 1.0555292544187542
# 0.9783076736869192
# 1.0568979480554181
# 0.978195791788758
# 1.0586358353918355
# 0.9805863659330837
# 1.0578408389969949
# 0.9796662257672865
# 1.0577548839247806
# 0.9819351629564841
# 1.0571089043031408
# 0.979880332245745
# 1.0581826258089475
# 0.9780316452605101
# 1.0577496580112407
# 0.9777673184040715
# 1.0606834341389533
# 0.9813555308531707
# 1.0593847089382233
# 0.98111128191416
# 1.0599045479413647
# 0.9798723790460379
# 1.0589702811368529
# 0.9776287373753194
# 1.059273733053951
# 0.9835429013525516
# 1.0583359675537247
# 0.9787909022370376
# 1.0569911596851875
# 0.9799755518624217
# 1.058952728937063
# 0.980085486184956
# 1.0579565508402002
# 0.9788012152720283
# 1.0577944794327854
# 0.9797330796338019
# 1.0570748393375193
# 0.9811914418534073
# 1.060117905013825
# 0.981113755527781
# 1.0606626350724118
# 0.9837993847649108
# 1.0596124810177505
# 0.9856244293350762
# 1.0578860771474952
# 0.980878395161843
# 1.0592664415139528
# 0.9806043942000703
# 1.0599708119484623
# 0.9821024694377447
# 1.0599355920826963
# 0.98156760259103
# 1.06077681139803
# 0.9824645716212903
# 1.0609633161524026
# 0.982815304199747
# 1.059330872228571
# 0.9811360381527565
# 1.0598155996233614
# 0.9828762848284373
# 1.0600898404153742
# 0.9800973754962045
# 1.0596256592016549
# 0.9803788791529556
# 1.0605780418911839
# 0.982474638233682
# 1.0592105293387124
# 0.9807743548636634
# 1.0597469882955786
# 0.9807005765910786
# 1.0609181880164757
# 0.9782424120215549
# 1.0622992261475332
# 0.9821794087687034
# 1.6332265090945677
# 1.5280849168339683
# 1.0627903552860152
# 0.983946473668863
# 1.0668406784749898
# 0.9849397631229603
# 1.0654815780033369
# 0.986417549490256
# 1.0656350665161047
# 0.9887889810702136
# 1.0671779000536028
# 0.9891050291296651
# 1.0644747134692996
# 0.988759658452989
# 1.066303069594313
# 0.985257858977411
# 1.067202288201595
# 0.9896537737999549
# 1.0676874984215452
# 0.9875079607693539
# 1.067010479099668
# 0.9914136329211991
# 1.0690950839667848
# 0.9892754317869744
# 1.0663484949938828
# 0.9881391752506795
# 1.0663986511975754
# 0.9886269416099678
# 1.0689568724799472
# 0.990058564491276
# 1.0686100122216593
# 0.9890082237761131
# 1.0664851887273266
# 0.9859611886010021
# 1.0661783312499864
# 0.9882696846312743
# 1.0674378475557484
# 0.9881673101621781
# 1.067522817656758
# 0.990086395151698
# 1.0672727766318892
# 0.9911965624038804
# 1.0661288019854944
# 0.9864093819959563
# 1.0658300589768201
# 0.9825514351014355
# Total execution time: 5157s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder3, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 246)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 246
# Processing: 100%|████████████████████████████████| 5/5 [02:34<00:00, 30.84s/it]
# Processing: 100%|██████████████████████████████| 80/80 [48:57<00:00, 36.71s/it]
# Processing: 100%|██████████████████████████████| 14/14 [07:50<00:00, 33.59s/it]
# Processing: 100%|████████████████████████████████| 8/8 [04:51<00:00, 36.39s/it]
# Processing: 100%|███████████████████████████████| 7/7 [13:28<00:00, 115.45s/it]
# Performing Scrubbing Correction
# 001_exp420_temp_00_p50_prot_04
# Processing: 100%|██████████████████████████████| 80/80 [00:34<00:00,  2.29it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.88it/s]
# 1.0638567245527313
# 0.985167299648741
# 1.0651328693324194
# 0.9825997319916409
# 1.0647855669181951
# 0.9864311429709857
# 1.066416419383631
# 0.9887395750771156
# 1.0656201624945956
# 0.9899587520509361
# 1.067846492367962
# 0.9875812375555741
# 1.0681892256615593
# 0.9871913893124095
# 1.06798160930808
# 0.9875623571642465
# 1.0661489986118715
# 0.9872368960921477
# 1.066289260571747
# 0.9903349163699233
# 1.065603704975622
# 0.9837982468214329
# 1.0664759490637281
# 0.9890074407820109
# 1.0650530689753201
# 0.9883697533991148
# 1.065938033882988
# 0.9848026016003809
# 1.066421911457756
# 0.9895431624146139
# 1.0651555800091141
# 0.988136168987339
# 1.0656764476363303
# 0.9878132774960244
# 1.0666987987199996
# 0.9850507331735086
# 1.0664624152935476
# 0.9862755372680754
# 1.065861480144285
# 0.9852852329845488
# 1.0654688542394746
# 0.988116137009935
# 1.0668293274609588
# 0.9882536190684994
# 1.0691712836089449
# 0.9898933856466684
# 1.6479056225986752
# 1.530031363913145
# 1.070697796985009
# 0.9906299886915542
# 1.0710775194732387
# 0.9884447993609069
# 1.0703147805086393
# 0.9861591742296074
# 1.0674540865680824
# 0.9905668460238471
# 1.0672491524765402
# 0.9870423534712054
# 1.0664559396133881
# 0.9873108377195037
# 1.0648268239224703
# 0.9854463121688293
# 1.0642243118866166
# 0.9883956648494335
# 1.0636414804324414
# 0.9864532365454959
# 1.065468042614124
# 0.9829371438012036
# 1.064364150003483
# 0.9833658228211472
# 1.0655152803718768
# 0.9886704746889423
# 1.6653171954251722
# 1.5564352952612188
# 1.0693058056471672
# 0.9915284225898541
# 1.0690813384279023
# 0.9862153050752129
# 1.0667731167887387
# 0.9876636072425439
# 1.0647455655886817
# 0.9840767535179793
# 1.0649495053618976
# 0.9815703601305333
# 1.0616006361110863
# 0.9826574879034532
# 1.063853354392984
# 0.9841700005046654
# 1.0635701546615681
# 0.9862912474254171
# 1.6279076872521803
# 1.5148986083999683
# 1.0678550308448314
# 0.9923830041174326
# 1.0677297766414382
# 0.9886965307668574
# 1.0665344640548433
# 0.9887598752311993
# 1.067140505476294
# 0.9862675625609633
# 1.068275476243223
# 0.990634343281077
# 1.0681532590123057
# 0.989090900416158
# 1.0700997769856444
# 0.9875494458791766
# 1.0714292023819636
# 0.9907026536648158
# 1.0716400623660602
# 0.9933620831174801
# 1.0693533193919613
# 0.9932660618097804
# 1.0730763005613895
# 0.9942443370763538
# 1.070078120982095
# 0.9924150034974484
# 1.0702403160372633
# 0.9908270281298976
# 1.066647458692293
# 0.9864999574907587
# 1.0681609632030598
# 0.9893666479310383
# 1.0688719350053804
# 0.9899750391227595
# 1.0683786434435127
# 0.9903029513201008
# 1.0689008468130963
# 0.9899572305577493
# 1.069657032438189
# 0.985964507802298
# 1.0685767388371936
# 0.9875403002873762
# 1.068293931570044
# 0.9914332528406856
# 1.0676783891678758
# 0.9916553158399123
# 1.0685649905784849
# 0.9866918256824392
# 1.0668826824400979
# 0.9888089114851796
# 1.069159677270478
# 0.9863668999212041
# 1.0676284884048939
# 0.9923221325582571
# 1.0674452058990211
# 0.9885473096616635
# 1.0679950932437556
# 0.9892704203687614
# 1.0657336641841155
# 0.9889011643312575
# 1.0675545859462368
# 0.9892460832247669
# 1.0681800199826827
# 0.9878141225822235
# 1.065480503975027
# 0.9883531140050982
# 1.0666078335573033
# 0.9855464914915949
# 1.0680221921447293
# 0.9887228475597928
# Total execution time: 4976s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder4, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 326)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 326
# Processing: 100%|███████████████████████████████| 5/5 [13:54<00:00, 166.99s/it]
# Processing: 100%|███████████████████████████| 30/30 [1:13:12<00:00, 146.41s/it]
# Processing: 100%|█████████████████████████████| 14/14 [41:49<00:00, 179.27s/it]
# Processing: 100%|███████████████████████████████| 8/8 [24:30<00:00, 183.78s/it]
# Processing: 100%|███████████████████████████████| 7/7 [24:58<00:00, 214.13s/it]
# Performing Scrubbing Correction
# 001_exp420_temp_00_p50_prot_05
# Processing: 100%|██████████████████████████████| 30/30 [00:12<00:00,  2.33it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.99it/s]
# 1.0673063647428203
# 0.9872927719082976
# 1.0674039697229043
# 0.9890357681560332
# 1.067361657060165
# 0.9864766574233693
# 1.0679688325366343
# 0.9881256364638192
# 1.0691380304679927
# 0.9894096059535874
# 1.0688190622554181
# 0.9872476686642926
# 1.0668773643017897
# 0.9884116489437268
# 1.0687666176753856
# 0.9913601677323852
# 1.0689742472780936
# 0.9904282567534795
# 1.0668536953869838
# 0.9896402637400578
# 1.0681326100520923
# 0.9891256478361877
# 1.0679381388687663
# 0.9895615867016099
# 1.0697824507539535
# 0.9909168691415278
# 1.068106855729005
# 0.9895856219461538
# 1.0698126234879748
# 0.9921072955308026
# 1.069343065233669
# 0.9915518811828887
# 1.0681632847415676
# 0.9900977818453834
# 1.0685837218426644
# 0.9906700815142273
# 1.0673519130350406
# 0.9924724477645231
# 1.0666585882735253
# 0.9889298605738187
# 1.0675353140096715
# 0.9893835233131759
# 1.069198249142552
# 0.9880801077446663
# 1.070388707274053
# 0.9918154498693634
# 1.0692766193451748
# 0.9900391277697932
# 1.0709310777261438
# 0.9925349640861462
# 1.0707904629297371
# 0.9934827230144575
# 1.0656868526569914
# 0.9860903607693295
# 1.066552942932956
# 0.9896842075380693
# 1.0638734874753986
# 0.9835368733290512
# 1.064589228477954
# 0.9856603982685178
# Total execution time: 10767s
