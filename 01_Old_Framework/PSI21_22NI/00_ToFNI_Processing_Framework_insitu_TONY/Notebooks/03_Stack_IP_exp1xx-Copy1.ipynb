# %% [markdown]
# # Image processing notebook: From overlap corrected to transmission
#
# ### 00 - Introduction
# This notebook demonstrates the use of Jupyter for a Time-of-Flight image processing task. The data corresponds to ToF neutron imaging of coin cells filled with different organic compounds and electrolytes.
#
# *Note: This notebook was written and tested on Windows 10. Running on Mac or Linux machines may need adjustments, e.g. in the path specificationsApplied processing*
#
# ### Applied processing
# The following processing parts from the averaged pulses, which were already overlap corrected:
#
# - filtering
# - Pulse averaging and separtion per experiments
# - identification and weighting of OBs for each experiment
# - scrubbing correction
# - intensity correction
# - transmission image generation
#
#
# ### Important Considerations
# This notebook starts from the point **after** the overlap correction presented in the image below. This step before (done in a separate notebook) format its destionation directory to be taken by this notebook to process the images correctly.
#
# Transmission Image:
#
# \begin{equation}
# T_{img} \rightarrow \frac{I}{I_{0}}=\frac{\frac{\bar{Img}}{OB_{weight}} - SBKG_{img}}{\frac{\bar{Ref}}{OB_{weight}} - SBKG_{ref}}
# \end{equation}

# %% [markdown]
# ## 01 Initial settings
# Import all the required libraries

# %%
import sys
sys.path.append(r'..\framework')
sys.path.append(r'..\proc_functions')
from stack_proc_func import *
from img_utils_mod import *
import scipy.signal as sp
# %matplotlib inline

# %% [markdown]
# ### Select directories
# Select the source directory. This directory is where the images **after** the overlap correction were saved.
# Select the destination directory. Here is where the transmission images are going to be saved.

# %%
# %load select_directory('src_dir')
src_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\00_Overlap_corrected\exp420"

# %%
# %load select_directory('dst_dir')
dst_dir = r"J:\700 Campaigns - internal\2021\PSI21_22NI\200_processed\01_Transmission_results\exp410"

# %% [markdown]
# ### Select working folders
# Once the directories are loaded, you can start to do a selection of the folders you want to process. <br>
# The next function loads the folders availableas a visual aid. However, you can avoid this step just by looking at the source folder in the windows explorer.

# %%
all_folders = prep_stack_dict(src_dir)
for key in all_folders.keys():
    print(key)
# Out:
# 000_ 00_ob_ini
# 001_exp410_temp_00_p0_prot_01
# 001_exp410_temp_00_p0_prot_02
# 001_exp410_temp_00_p0_prot_03
# 001_exp410_temp_00_p0_prot_04
# 001_exp410_temp_00_p0_prot_05
# 097_ob
# 098_ref_bb
# 099_ob

# %% [markdown]
# For this test we will select some folders that we want to process as '`proc_folder`' and our reference as '`ref_folder`'.
#
# * _note: `proc-folder` can take several strings as value, for that reason is a list of strings. On the other hand, `ref_folder` is always one, for that reason it is just a string._

# %%
proc_folder0 = ['001_exp410_temp_00_p0_prot_01']
proc_folder1 = ['001_exp410_temp_00_p0_prot_02']
proc_folder2 = ['001_exp410_temp_00_p0_prot_03']
proc_folder3 = ['001_exp410_temp_00_p0_prot_04']
proc_folder4 = ['001_exp410_temp_00_p0_prot_05']

ref_folder = '098_ref_bb'

# %% [markdown]
# ## 02 Filtering process definition
# Here we define the process that each image will have before the pulse averaging (if any).
#
# * _note: The sequence generated must contain the names of each function and at the end the 'stack_avg' function which performs the pulse averaging. <br> i.e.  test_seq = [`function_1`, `function_2`, `more functions`, `stack_avg`]_

# %% [markdown]
# ### White spots filtering
# The white spots are removed by applying a median filter of size 'ws_filter_size'

# %%
from skimage.filters import gaussian, median, meijering
from skimage.morphology import disk

def ws_filter(src_img, ws_filter_size, **kwargs):
    return sp.medfilt2d(src_img.astype('float32'), ws_filter_size)

def outlier_removal (img, threshold, **kwargs):
    mask_x = np.where(img <= threshold)[0]
    mask_y = np.where(img <= threshold)[1]
    for x, y in zip(mask_x, mask_y) :
        slice = img[max(0, x-1):x+1, max(0,y-1):y+1] # assuming you want 5x5 square
        img[x,y] = np.mean([i for i in slice.flatten() if i > threshold])  # threshold is 0
    return img

# %%
#roi_crop = [1, 356, 509, 129]

# %%
test_seq = [outlier_removal, stack_avg]

# %% [markdown]
# ## 03 Filter testing
# The `test_filter_stack` function test the filters given in the `test_seq` list and prints the image.<br> A selection of a testing folder named `test_folder` is required to proceed with the image checkout. <br>
# -If no specific image is selected, it automatically selects the image at the median point in the stack.<br>
#
# * _note: if the filtering functions inserted in the `test_seq` require aditional arguments or variables, they can be given as `**kwargs` inside the function parameters. i.e `ws_filter_size = 5` was given in the function for the ws_filter usage._

# %%
test_folder = '001_exp410_temp_00_p0_prot_01'
img = test_filtering_stack (src_dir,dst_dir, test_folder = test_folder, test_seq = test_seq, give_img=True, threshold = 0,
                            ws_filter_size = 3)
# Out:
# threshold = 0
# ws_filter_size = 3
# Averaging: 100%|███████████████████████████████| 78/78 [00:27<00:00,  2.80it/s]

# %% [markdown]
# ### Confirm the operations sequence
# After you are satisfied with the result, write the real sequence `seq` that will be used for all the images.

# %%
seq = [outlier_removal]

# %% [markdown]
# ## 04 Selecting ROIS and other variables
# Each campaign is different, if there are some requirements that the processing require, you can insert them as `**kwargs`. <br>
# In the case of this specific campaing (PSI19_03NI), the MCP detector did not adquire correctly the first 9 images in each process. For that reason, the processing needs to remove those images. Thus, we can slice the folder by givin the values that we want with `start_slice` and `end_slice`.
#
# * _note: If we want to slice the starting but not the end, it is just required to give the beginning (`start_slice`) and leave `end_slice` blank as in the next example._

# %% [markdown]
# ### ROI selection (program still needs the implementation of the CSV option)
# One important parameter are the ROIs, specifically the non-changing-area (nca). Fo that reason, we do a use an interactive command to select them.
#
# If more ROIs were selected (other than the first -nca-), these will be used to create a CSV file at the end with the all the transmission values included. <br>**waiting for implementation in stack_batch_proc**
#
# The window for ROI selection still open in a separate window, I am checking the way to have it printed in the notebook to avoid changing any mistake
#
# * _note: the option 'flip_image = True' is required to agree with imageJ format of showing the image. In stack_batch_proc it is implemented in the intensity correction part (TFC_corr). The modifications done to img_utils _
#
# **to select several ROIs: for each ROI selected, press ENTER, when finish, press ESC**

# %%
# %load select_rois(img, list_rois = ['nca'])
nca = [119, 400, 304, 80]

# %% [markdown]
# To agree with the selected ROIs, the image is shown with its labeling, being label 1 the first ROI selected i.e nca, second label 2 and so forth

# %%
show_img(img, dr = [nca])

# %% [markdown]
# ## 05 BB mask
# The BB mask is a fits image saved in the source directory. if all the experiments are aligned, one BB mask can be used. However, if there are misalignments, several BB masks must be given.
#
# **a program that creates the BB mask for that specific experiment would be extremly useful in this case so we do not need to care anymore about BBs**
#
# For the moment being and as an example, the program takes a real (for testing) BB mask to include it in the process

# %%
ref_mask_img = get_img(src_dir + '/bb_mask_ref.fits')
img_mask_img = get_img(src_dir + '/bb_mask_prot.fits')

# %% [markdown]
# ## 06 Run first transmission image test
# This will give you one transmission image as an example of the whole process.
#
# Set a starting and ending slice (to speed up the process, do not choose more tan 10 images or do it in different parts of the spectrum)

# %%
stack_test = stack_batch_proc (src_dir, dst_dir, ref_mask_img,img_mask_img, proc_folder = [test_folder], 
         ref_folder = ref_folder, avg_seq = seq, save_results = False, start_slice = 30, end_slice = 40, 
         print_TFC = True, nca=nca, threshold = 0, stack_avg=False, scrubbing=True, initial_HE_LE = (False, [3,23],[60,80]))

# %% [markdown]
# ### Testing the NCA region
#
# This region is characterized for having a value of 1. The process might have an error if this region has values greater that 0.05% of the theoretical one.

# %%
for key, val in stack_test.items():
    print(key)
    for key2, im in val.items():
        print(key2)
        nca_reg =[]
        for arr in im:
            nca_reg.append(np.mean(roi_in_image(arr[0],nca)))
        print('value cropped reg {}'.format(np.mean(nca_reg)))
        print(nca_reg)
print(len(nca_reg))
print('Average value in the NCA is {}'.format(np.mean(nca_reg)))

# %% [markdown]
# ## 07 Full image processing
# After all tests are correct, you can process and do the full image process for all the folders that you want with the captured parameters.
#
# The result of using the next function is that all the transmission images generated with it are saved with a .fits extension in your destination folder and HE and LE sections will be saved in another 2 folders.

# %% [markdown]
# __Note:__ If you are sure fo the process, you can leave `proc_folder` empty `proc_folder = []`,the program will process all folders included in the source directory.

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder0, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 6)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 6
# Processing: 100%|████████████████████████████████| 6/6 [03:07<00:00, 31.22s/it]
# Processing: 100%|██████████████████████████████| 78/78 [48:51<00:00, 37.58s/it]
# Processing: 100%|██████████████████████████████| 14/14 [08:27<00:00, 36.24s/it]
# Processing: 100%|████████████████████████████████| 8/8 [04:50<00:00, 36.36s/it]
# Processing: 100%|████████████████████████████████| 7/7 [04:15<00:00, 36.44s/it]
# Performing Scrubbing Correction
# 001_exp410_temp_00_p0_prot_01
# Processing: 100%|██████████████████████████████| 78/78 [00:34<00:00,  2.28it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.97it/s]
# 0.9424699529881934
# 0.8712486297437801
# 0.9375098340464609
# 0.8632299934224283
# 0.9356299750983491
# 0.864086696804189
# 0.9374344841913405
# 0.8624807063928872
# 0.9371799244418184
# 0.862925718676009
# 0.935545249510162
# 0.8601050966667133
# 0.9348035261583559
# 0.8624127590169237
# 0.9347553485645933
# 0.8621061270086798
# 0.9357473487090943
# 0.8628831966084402
# 0.9364650211259482
# 0.86285964353775
# 0.9355414056122691
# 0.863890656617013
# 0.9346893003931049
# 0.8607793731014056
# 0.9351089819907624
# 0.8614890505876694
# 0.9357981484589925
# 0.8626522628546609
# 0.9353539955299308
# 0.8645573160837207
# 0.9349897396852906
# 0.8638879586890664
# 0.9356566664751736
# 0.8620081148829715
# 0.9351660159998628
# 0.8629510953325371
# 0.934898943926742
# 0.8619872873158174
# 0.9346487456138804
# 0.8598446023605104
# 0.9346820520825064
# 0.8612390054295226
# 0.9357613933799718
# 0.862937185353441
# 0.9314975458466119
# 0.8580113018008458
# 0.9307191771792305
# 0.8604133572056929
# 0.9334790673661516
# 0.8619012624947823
# 0.940561519415577
# 0.8684149210118589
# 0.9419903694487776
# 0.8664383647885244
# 1.160816863502669
# 1.0814931452041183
# 0.9478791200204006
# 0.8663983548507991
# 0.9480994529232212
# 0.8658267440307021
# 0.9478976923613784
# 0.868430149521701
# 0.9476444522886902
# 0.8683926699190061
# 0.944660061016256
# 0.8693865423807942
# 0.9461499371921622
# 0.8694335304227764
# 0.9470028219656977
# 0.8705207619858668
# 0.9464621672759325
# 0.8660246494336566
# 0.9486430765337466
# 0.8693018697482572
# 0.9468351283453901
# 0.8698648289659092
# 0.9465577340058692
# 0.8681473143783102
# 0.9447854741237621
# 0.8675875259210828
# 0.9461938921336649
# 0.8666344228167918
# 0.9464059746555517
# 0.8698203384129312
# 0.9477275140557114
# 0.8729645439059575
# 0.94793050736511
# 0.8708419982077659
# 0.946698475155622
# 0.8680315398809879
# 0.9466142473259301
# 0.8712448451835325
# 0.9460300995503642
# 0.8699938281085987
# 0.9474425467349069
# 0.8707036840955356
# 0.9455064512149169
# 0.8680198809239759
# 0.9483113413433714
# 0.87128155703884
# 0.9474247251740718
# 0.8706564647855202
# 0.9474827318544278
# 0.8726863498707883
# 0.9480720931748463
# 0.8697323364353243
# 0.9460533008247778
# 0.8729733077946944
# 0.9456195275735471
# 0.8685515306871008
# 0.9471272698534872
# 0.871789143473485
# 0.9469090291075125
# 0.8698048076605125
# 0.9464123774070301
# 0.8693670481050435
# 0.9463272681602947
# 0.8737706579101683
# 0.9451606369878949
# 0.8720852681428485
# 3.4077930480328287
# 3.226616575853908
# 0.9566045028688351
# 0.8778231726981394
# 1.4515223308707152
# 1.339542759237963
# 0.9542684720805398
# 0.8735348781438386
# 0.9523506259629607
# 0.8744775448773282
# 0.9550761727029186
# 0.8764000353879011
# 0.9518440832741862
# 0.8739236119111822
# 0.9499570355306655
# 0.873990860829943
# 0.9513336129661688
# 0.8745312011847167
# 0.9512245753238278
# 0.8742634637550711
# 0.9488133939779418
# 0.8713251501676238
# 0.9513514228151135
# 0.87610581010877
# 0.9516558905038718
# 0.8765033368077565
# 0.9529423250969237
# 0.8759251071012557
# 0.9526419181852982
# 0.8775925119244407
# 0.9514232733928686
# 0.875054954221932
# 0.9525667919371571
# 0.8747926400228877
# 0.9532289535757192
# 0.8761013893813628
# Total execution time: 4437s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder1, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 86)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 86
# Processing: 100%|████████████████████████████████| 6/6 [02:51<00:00, 28.64s/it]
# Processing: 100%|██████████████████████████████| 77/77 [45:49<00:00, 35.70s/it]
# Processing: 100%|██████████████████████████████| 14/14 [06:57<00:00, 29.84s/it]
# Processing: 100%|████████████████████████████████| 8/8 [04:01<00:00, 30.19s/it]
# Processing: 100%|████████████████████████████████| 7/7 [03:29<00:00, 29.93s/it]
# Performing Scrubbing Correction
# 001_exp410_temp_00_p0_prot_02
# Processing: 100%|██████████████████████████████| 77/77 [00:33<00:00,  2.27it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.95it/s]
# 0.9547523527341333
# 0.8800292626442277
# 0.9520245562467804
# 0.8736887501738801
# 0.9522920537934688
# 0.876476999231112
# 0.9527988409029567
# 0.8810053737122718
# 0.9527387480453501
# 0.8760466008589265
# 0.953721098183219
# 0.8751629645985775
# 0.9537312607796544
# 0.8806992219582767
# 0.9527210054837413
# 0.8744758177855011
# 0.9522757100672776
# 0.8786133894602227
# 0.9545344481123055
# 0.8782041637286337
# 0.954061368197668
# 0.8777169611520762
# 0.9531845652466503
# 0.8772416888285214
# 0.9537477263749038
# 0.8794823729321133
# 0.9530840611777606
# 0.8760359239792348
# 0.955382011373694
# 0.8790995355224847
# 0.9551198566108973
# 0.8774746956367981
# 0.9544774684263437
# 0.8782844587881269
# 0.9547152699221755
# 0.8776273034230505
# 0.9548447579721194
# 0.8805798302220951
# 0.9612865956785301
# 0.8842304768400175
# 0.9551951740787612
# 0.877998990495642
# 0.953216710783813
# 0.8787489724059369
# 0.9523962113650327
# 0.8763737282647187
# 0.9540478954311137
# 0.8760824421095631
# 0.954694585036136
# 0.8764012738441851
# 0.9542738103793709
# 0.8782829584360076
# 0.9925381024303789
# 0.8988635113923464
# 0.9921241907691493
# 0.8996541792340126
# 0.9911607131115595
# 0.8951385049581422
# 0.988813009208237
# 0.8960721760898198
# 0.9885333330494667
# 0.8992241892624058
# 0.9901429359467538
# 0.899155061996869
# 0.9868040500763878
# 0.8978883252804123
# 0.988321958344845
# 0.8967404865759953
# 0.987427640938817
# 0.8968459381225229
# 0.9883817452455076
# 0.8976189644470405
# 0.9868699800503926
# 0.8972946127288274
# 0.9855992471556329
# 0.8987447141298346
# 0.9843768006632984
# 0.8999711273859224
# 0.9854632947167115
# 0.8982477239517423
# 0.9882144357425359
# 0.9014015504922392
# 0.9858962856375211
# 0.8999724783338678
# 0.9829730089417881
# 0.8983995492280745
# 0.9817741996878987
# 0.8979848995670976
# 0.9795979518649471
# 0.897290797912535
# 0.9813361156500625
# 0.8994559451757859
# 0.9812453053729339
# 0.9018045901926597
# 0.982027273354906
# 0.9010821256826594
# 0.9830863067743681
# 0.9020092863277875
# 0.9810003045689717
# 0.8984509317117331
# 0.983208069032663
# 0.8993276061645494
# 0.9803031902691751
# 0.8990990652695715
# 0.9824019007840223
# 0.9001960542096931
# 0.9822688220218135
# 0.9027238641019769
# 0.9835927673328924
# 0.9028605638433372
# 0.9838176789237802
# 0.9029697153691691
# 0.9845200668707417
# 0.902446422665099
# 0.985589913350066
# 0.9046787221825898
# 0.984325374132189
# 0.9027919877202554
# 0.9840048325207038
# 0.9038561773291648
# 0.9843296632328995
# 0.9026124498953156
# 0.9853901267379608
# 0.9029454105368726
# 0.9828246961620765
# 0.9028368592286936
# 0.9832861509526476
# 0.9042382357229302
# 0.9828961524633743
# 0.9045272836505404
# 0.9825624121839951
# 0.9032007399373108
# 0.9829095066723312
# 0.9010697827777298
# 0.9826849019440478
# 0.9002126501046283
# 2.13116136631187
# 1.9861809145268272
# 0.9869556802022266
# 0.9084126225823936
# 0.9866222007530431
# 0.907668943057704
# 0.9862867207741697
# 0.9061374482045264
# 0.9867533393922807
# 0.9060031333464582
# 0.9873235795313817
# 0.9072474957341858
# 0.9869542612169233
# 0.9037700011172967
# 0.9872700532524649
# 0.9071727498555788
# 0.9857711655305662
# 0.9096213511106527
# Total execution time: 4035s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder2, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 166)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 166
# Processing: 100%|████████████████████████████████| 6/6 [02:45<00:00, 27.54s/it]
# Processing: 100%|██████████████████████████████| 80/80 [45:46<00:00, 34.33s/it]
# Processing: 100%|██████████████████████████████| 14/14 [07:01<00:00, 30.08s/it]
# Processing: 100%|████████████████████████████████| 8/8 [04:00<00:00, 30.02s/it]
# Processing: 100%|████████████████████████████████| 7/7 [03:27<00:00, 29.60s/it]
# Performing Scrubbing Correction
# 001_exp410_temp_00_p0_prot_03
# Processing: 100%|██████████████████████████████| 80/80 [00:35<00:00,  2.24it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.98it/s]
# 0.9849441249933312
# 0.904566715669885
# 0.9855608888851649
# 0.9081615610317599
# 0.9848530624530192
# 0.9022799887479013
# 0.9830940768367024
# 0.9067929377000644
# 0.9833610229302808
# 0.9025283568170497
# 0.9802755306982582
# 0.9029792208618528
# 0.9829756263173737
# 0.9041146299137696
# 0.9853619343175853
# 0.905650896155444
# 0.9846456590270812
# 0.9019387965370642
# 0.9854180422489303
# 0.903148966429106
# 0.9811887913139492
# 0.9030570626751908
# 0.9833993775562268
# 0.903786959878348
# 0.983929204269307
# 0.9059931293166326
# 0.9835348972949647
# 0.9069219252974884
# 1.5167652875268798
# 1.4025028155994428
# 0.9808781894001739
# 0.9030673994139545
# 0.965937085403175
# 0.8909793748046538
# 0.9591668085777156
# 0.8834652682616271
# 0.957657706442499
# 0.8810885711549653
# 0.9571991602135422
# 0.880440402511823
# 0.9586540609792243
# 0.8824060922916271
# 0.9569981214880683
# 0.8825176486400819
# 0.958822220766191
# 0.8827102147619553
# 0.9580583027666283
# 0.8824278558508726
# 0.9563706087439453
# 0.8830223008426421
# 0.9578035254194074
# 0.8827055318301673
# 0.9560782337344451
# 0.8801315124064003
# 0.9569069636291215
# 0.8812624370048437
# 1.4735158982143477
# 1.3707162739461984
# 0.9597710775065743
# 0.885251193809254
# 0.9613734194421899
# 0.8861612499069418
# 0.9572885595994072
# 0.8808585641304035
# 1.419181726211521
# 1.3169807706255485
# 0.9698639262341499
# 0.8934423876505978
# 0.9588385549668279
# 0.8841658737328614
# 0.9586123754846894
# 0.8821573361781252
# 0.9569125569144504
# 0.882694366688523
# 0.9575978881249162
# 0.8811621220185393
# 0.9598175835278421
# 0.8851660839764545
# 0.9594189825487008
# 0.8831293320338934
# 0.9583581661135397
# 0.8828902218793253
# 0.9625677498565477
# 0.8864772766402165
# 0.95979456987314
# 0.8842156837424258
# 0.959966274977408
# 0.8836466031767252
# 0.9578822133333594
# 0.8833887433854871
# 0.9578814453581039
# 0.8828879549456038
# 0.9601042487589405
# 0.8831507163858385
# 0.9582629638372165
# 0.8852704703154652
# 0.9584480237275251
# 0.8841443411148333
# 0.9576192704971958
# 0.8834334946852598
# 0.9581323929662733
# 0.8858963700037737
# 0.9584278454272627
# 0.8823924260652952
# 0.957856562369496
# 0.8843611039401904
# 0.9615070010378419
# 0.8853330540678229
# 1.365038812774183
# 1.2765346615830504
# 4.427339809087276
# 4.1911279851251635
# 0.9671556916466333
# 0.8915097511473961
# 0.9662053095419213
# 0.890569894962138
# 0.9678195104321864
# 0.8882800085994913
# 0.9668416804982325
# 0.8854684359685064
# 0.9678506628613783
# 0.8878819268855634
# 0.9665166347144568
# 0.8884766744063696
# 0.9688757545261796
# 0.8932201683598565
# 0.9659153855929605
# 0.8908965963454204
# 0.9677592607016261
# 0.8917618637099213
# 0.9662196217083846
# 0.8914783663180298
# 0.9652133619477357
# 0.8882672679253678
# 0.9650118467850687
# 0.8917677858133749
# 0.9649402684012809
# 0.8898001008956664
# 0.9633145905102922
# 0.8877921169321572
# 0.9647671835618068
# 0.8872100175864769
# 0.9659293594756556
# 0.8883827659237188
# 0.9648229662866111
# 0.8887475185094748
# 0.9628904450887498
# 0.8855479543861373
# 0.9558043657466773
# 0.8830202768809772
# 0.9587654912603143
# 0.8854696954715084
# 0.9584057049512974
# 0.8831434679058949
# 0.9559418621757961
# 0.882662647825091
# 0.9576467046259189
# 0.8829972253276808
# 0.9570229368212034
# 0.8831637911500371
# Total execution time: 4044s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder3, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 246)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 246
# Processing: 100%|████████████████████████████████| 6/6 [02:46<00:00, 27.72s/it]
# Processing: 100%|██████████████████████████████| 78/78 [42:40<00:00, 32.83s/it]
# Processing: 100%|██████████████████████████████| 14/14 [07:08<00:00, 30.58s/it]
# Processing: 100%|████████████████████████████████| 8/8 [04:11<00:00, 31.44s/it]
# Processing: 100%|████████████████████████████████| 7/7 [03:30<00:00, 30.14s/it]
# Performing Scrubbing Correction
# 001_exp410_temp_00_p0_prot_04
# Processing: 100%|██████████████████████████████| 78/78 [00:36<00:00,  2.14it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.76it/s]
# 0.959509146225106
# 0.8831132665778159
# 0.9577646143427005
# 0.8835709477572453
# 0.9603253439011368
# 0.8873941737801794
# 0.960725375876943
# 0.887358648319619
# 0.9601307182307455
# 0.8830295183107351
# 0.9572361957215334
# 0.8849501835637734
# 0.9584418173962137
# 0.8857819801253115
# 0.9611604822557756
# 0.888401956262692
# 0.9621521542267858
# 0.8863840400053113
# 1.4958090137641789
# 1.3868743974979358
# 1.0099166621029854
# 0.9298255598641048
# 1.270619602149596
# 1.1735639673107914
# 0.957791225627839
# 0.8795516907099945
# 0.9560261549029965
# 0.8847820380322892
# 0.9576961498721857
# 0.881025552329643
# 0.9575067282225037
# 0.8842972091385654
# 0.959749681013834
# 0.8835714976531024
# 0.9548366923439325
# 0.8830151518079108
# 0.9568466392257498
# 0.883488553707652
# 0.9580545945171097
# 0.8843475371976055
# 0.9581408158154808
# 0.88478426733319
# 0.9598844192351725
# 0.8853236092039711
# 0.9588673748589612
# 0.8834641581946322
# 0.9597750868395528
# 0.8849050767492251
# 0.9589822378214308
# 0.8856017790122398
# 0.9597161922246494
# 0.8824192697676322
# 0.9574443433357922
# 0.8829859188860135
# 0.9597407918215505
# 0.8891614556247501
# 0.9603807579289559
# 0.8864872748033339
# 0.9613105155367422
# 0.8862161525120826
# 0.963990318614989
# 0.8899682012427793
# 0.9613520034564734
# 0.8868343637734311
# 0.9589633945095661
# 0.8841628391190719
# 0.9600973661493091
# 0.8818798370784506
# 1.169054540111306
# 1.0759767365872464
# 0.9647338817394917
# 0.8842510303824573
# 0.9656043922477743
# 0.8843817303003719
# 0.9625272105967445
# 0.8886005471881111
# 0.961842181168509
# 0.883912541931833
# 0.9612134554544228
# 0.8857979073309369
# 0.9606135143261451
# 0.8850495014114698
# 0.9631754428539117
# 0.8855978251603528
# 0.9663210254098795
# 0.8861254237757744
# 0.9627688744466748
# 0.885526945877871
# 0.9616400030857849
# 0.8855198969261244
# 0.9641031668343916
# 0.8866440624829247
# 0.9636111577921194
# 0.8875319317384649
# 0.962749168136185
# 0.8874926736645902
# 0.9627210026977207
# 0.8864925239063268
# 0.9625900884075979
# 0.8876277609825739
# 0.9647584449715685
# 0.8880390899761874
# 0.9653264091092713
# 0.8874250398280126
# 0.9617271149344482
# 0.8881913736518389
# 0.9619686436728909
# 0.8877845574893942
# 0.962147645455327
# 0.8863670984865443
# 0.9625136381560384
# 0.8858762383810797
# 0.9625766478245074
# 0.8855763977489001
# 0.9646230843577683
# 0.8877809197592446
# 0.9648701598056788
# 0.8903331170695163
# 0.9656935678295862
# 0.8894604462460981
# 0.9661194358652613
# 0.8903326273359766
# 1.5214048447518678
# 1.4212629240275336
# 0.9661621693885638
# 0.8922915355416198
# 1.4951607024575853
# 1.3894304885055127
# 0.9647248414901437
# 0.8884748839627921
# 0.9632432825925384
# 0.887265934917507
# 0.9665114855054083
# 0.8876846852978822
# 0.9704791331731589
# 0.8903189080370179
# 0.9688488551542423
# 0.8902721146444563
# 0.9666208086590399
# 0.8945238284249396
# 0.9691797386435806
# 0.8904804208664588
# 0.9693164138963832
# 0.8931298319812061
# 0.9735730756179072
# 0.8965191399543567
# 0.9733944009699736
# 0.89544400970366
# 0.9725651305720231
# 0.8962696144655578
# 0.9723555419392979
# 0.8970235478999734
# 0.9722007095224728
# 0.8963035610388294
# 0.9720182961988587
# 0.8972682497157063
# Total execution time: 3850s

# %%
stack_batch_proc (src_dir, dst_dir, ref_mask_img, img_mask_img, proc_folder = proc_folder4, print_TFC = True,
                  ref_folder = ref_folder, avg_seq = seq ,nca=nca, threshold = 0, stack_avg=False, scrubbing=True,
                 start_numb = 326)
# Out:
# print_TFC = True
# nca = [119, 400, 304, 80]
# threshold = 0
# stack_avg = False
# start_numb = 326
# Processing: 100%|████████████████████████████████| 6/6 [02:47<00:00, 27.96s/it]
# Processing: 100%|██████████████████████████████| 55/55 [30:50<00:00, 33.65s/it]
# Processing: 100%|██████████████████████████████| 14/14 [07:02<00:00, 30.17s/it]
# Processing: 100%|████████████████████████████████| 8/8 [04:11<00:00, 31.48s/it]
# Processing: 100%|████████████████████████████████| 7/7 [03:31<00:00, 30.19s/it]
# Performing Scrubbing Correction
# 001_exp410_temp_00_p0_prot_05
# Processing: 100%|██████████████████████████████| 55/55 [00:23<00:00,  2.30it/s]
# 098_ref_bb
# Processing: 100%|████████████████████████████████| 2/2 [00:00<00:00,  4.75it/s]
# 0.9733069491051735
# 0.8958769613670358
# 0.9727581710046499
# 0.897158167203538
# 0.9729827698415905
# 0.8959815058292345
# 0.9734525674392329
# 0.8968184398731377
# 0.9717237458463757
# 0.8960093281981057
# 0.9714583438337464
# 0.8958945748943756
# 0.9752748629286029
# 0.8989801078936709
# 0.9722242462286681
# 0.8947949602797236
# 0.9756997643706681
# 0.8983558862275739
# 0.9730880658602508
# 0.8965805368145385
# 0.9751072240633828
# 0.8981001436929761
# 0.9771032089815632
# 0.9011830802523261
# 0.9748493285948655
# 0.9018139756215588
# 0.9742327052812998
# 0.8998460753228722
# 0.9757233168031016
# 0.8984742167988844
# 0.9720871479655457
# 0.8968400134878395
# 0.9727615263946146
# 0.8977185541827843
# 0.9707602662393917
# 0.8966804828716216
# 0.9731400966835797
# 0.8955152391732721
# 0.9714821181465705
# 0.8989408930935755
# 0.9739360122497132
# 0.8984840069910591
# 0.9741493617187846
# 0.8982230760557166
# 0.9712519065009861
# 0.8990595498736992
# 0.9735015201396716
# 0.8977117749612643
# 0.9719522724610551
# 0.9001539590491674
# 0.975062891215222
# 0.8980232532478473
# 0.9755684305956784
# 0.8962159940470784
# 0.9753255903705252
# 0.8984898736812937
# 0.9747264357602977
# 0.9018485927597739
# 0.9760249860804691
# 0.8997889801642239
# 0.9752442933549661
# 0.8999233902697685
# 0.9749494092303758
# 0.8997685023244147
# 0.9767257041552898
# 0.8980137868566561
# 0.9762330161113205
# 0.8990720659563946
# 0.9769254055152916
# 0.900038496676209
# 0.9755423434948165
# 0.9025921646590697
# 0.9742324448344318
# 0.8996853696449124
# 0.9763041364243602
# 0.9011154977011322
# 0.9759202668294533
# 0.899271422074746
# 0.9759186001183092
# 0.8992185408362209
# 0.9759480920497003
# 0.9015589184106586
# 0.9753392672986405
# 0.9009234531769285
# 0.9760605500485253
# 0.8990680764188161
# 0.9751295929515057
# 0.8994418729345249
# 0.9758874673259991
# 0.8982102645225077
# 0.9747634930993362
# 0.8969736570479785
# 0.975829793491713
# 0.9005707551508474
# 0.9754511430760567
# 0.900469368390041
# 0.975013119017021
# 0.8990574302945236
# 0.9741486181623554
# 0.8997408505528702
# 0.9743653829210741
# 0.9004641435544919
# 0.9742859081741785
# 0.8986977951218085
# 0.9761287612186481
# 0.9005097412724863
# 0.974878908180501
# 0.8994958885990822
# 0.9743929786041803
# 0.8983938686028841
# Total execution time: 3042s
